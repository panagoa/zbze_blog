# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece
from tokenizers.trainers import WordPieceTrainer
from tokenizers.pre_tokenizers import Whitespace

tokenizer = Tokenizer(WordPiece(unk_token="[UNK]"))

tokenizer.pre_tokenizer = Whitespace()

trainer = WordPieceTrainer(
    vocab_size=2000,
    min_frequency=2,
    special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]"]
)

# %%
files = [ 
    '../data/processed/oshhamaho.txt',
]

tokenizer.train(files, trainer)

# %%
sorted(tokenizer.get_vocab().items(), key=lambda x: x[1])
# Out:
# [('[PAD]', 0),
#  ('[UNK]', 1),
#  ('[CLS]', 2),
#  ('[SEP]', 3),
#  ('[MASK]', 4),
#  ('!', 5),
#  ('(', 6),
#  (')', 7),
#  ('*', 8),
#  (',', 9),
#  ('-', 10),
#  ('.', 11),
#  ('0', 12),
#  ('1', 13),
#  ('2', 14),
#  ('3', 15),
#  ('4', 16),
#  ('5', 17),
#  ('6', 18),
#  ('7', 19),
#  ('8', 20),
#  ('9', 21),
#  (':', 22),
#  (';', 23),
#  ('?', 24),
#  ('I', 25),
#  ('i', 26),
#  ('«', 27),
#  ('»', 28),
#  ('×', 29),
#  ('Ё', 30),
#  ('А', 31),
#  ('Б', 32),
#  ('В', 33),
#  ('Г', 34),
#  ('Д', 35),
#  ('Е', 36),
#  ('Ж', 37),
#  ('З', 38),
#  ('И', 39),
#  ('Й', 40),
#  ('К', 41),
#  ('Л', 42),
#  ('М', 43),
#  ('Н', 44),
#  ('О', 45),
#  ('П', 46),
#  ('Р', 47),
#  ('С', 48),
#  ('Т', 49),
#  ('У', 50),
#  ('Ф', 51),
#  ('Х', 52),
#  ('Ц', 53),
#  ('Ч', 54),
#  ('Ш', 55),
#  ('Щ', 56),
#  ('Ъ', 57),
#  ('Ы', 58),
#  ('Ь', 59),
#  ('Э', 60),
#  ('Ю', 61),
#  ('Я', 62),
#  ('а', 63),
#  ('б', 64),
#  ('в', 65),
#  ('г', 66),
#  ('д', 67),
#  ('е', 68),
#  ('ж', 69),
# ...

# %%
import pandas as pd
words_df = pd.read_csv('../data/processed/word_freqs/freq_1000000_oshhamaho.csv')
words_df['tokens'] = words_df['word'].apply(lambda x: '-'.join([t.replace('##', '') for t in tokenizer.encode(x).tokens]))
words_df
# Out:
#                      word    freq                 tokens
# 0                       ,  428272                      ,
# 1                       .  297212                      .
# 2                       и  133661                      и
# 3                       –   92993                      –
# 4                       «   38086                      «
# ...                   ...     ...                    ...
# 483333           уихьэжын       1             уи-хьэ-жын
# 483334        дутIыпщыжри       1         д-утIы-пщы-жри
# 483335  скIэригъэкIыркъым       1  с-кIэр-игъэ-кIыр-къым
# 483336             Таксир       1              Т-ак-си-р
# 483337            гъэщIэр       1               гъэ-щIэр
#
# [483338 rows x 3 columns]
