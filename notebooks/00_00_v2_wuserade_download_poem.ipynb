# %%
import requests

class UseradeClient:
    def __init__(self, base_url="https://wuserade.onrender.com"):
        self.base_url = base_url

    def get_poems(self, page=1):
        """Получение списка стихов."""
        url = f"{self.base_url}/poems"
        params = {"page": page}
        response = requests.get(url, params=params)
        return response.json()

    def get_poem_by_id(self, poem_id):
        """Получение стиха по ID."""
        url = f"{self.base_url}/poems/{poem_id}"
        response = requests.get(url)
        return response.json()

    def get_authors(self, page=1):
        """Получение списка авторов."""
        url = f"{self.base_url}/authors"
        params = {"page": page}
        response = requests.get(url, params=params)
        return response.json()

    def get_author_by_id(self, author_id):
        """Получение информации об авторе по ID."""
        url = f"{self.base_url}/authors/{author_id}"
        response = requests.get(url)
        return response.json()

    def get_poems_of_author(self, author_id):
        """Получение стихов конкретного автора."""
        url = f"{self.base_url}/authors/{author_id}/poems"
        response = requests.get(url)
        return response.json()

    def search_poems(self, search_query):
        """Поиск стихов."""
        url = f"{self.base_url}/poems/search"
        params = {"q": search_query}
        response = requests.get(url, params=params)
        return response.json()

    def get_themes(self):
        """Получение списка тем."""
        url = f"{self.base_url}/themes"
        response = requests.get(url)
        return response.json()
    
    def all_poems(self):
        """Генератор для получения всех стихов, обходя пагинацию."""
        current_page = 1
        total_pages = 1  # Начинаем с 1, чтобы войти в цикл

        while current_page <= total_pages:
            response = self.get_poems(page=current_page)
            if 'total_pages' in response:
                total_pages = response['total_pages']

            if 'poems' in response:  # Предполагаем, что стихи возвращаются в ключе 'data'
                for poem in response['poems']:
                    yield poem

            current_page += 1
    
    # Здесь добавьте оставшиеся методы, если они есть.

# Пример использования
client = UseradeClient()

poems = {}

for poem in client.all_poems():
    poems[poem['id']] = poem

# %%
len(poems)
# Out:
# 3829

# %%
import json

with open('../data/external/wuserade/poems.json', 'w', encoding='utf-8') as f:
    json.dump(poems, f, ensure_ascii=False, indent=4)

# %%
import json
with open('../data/external/wuserade/poems.json', 'r', encoding='utf-8') as f:
    poems = json.load(f)

# %%
import pandas as pd

df = pd.DataFrame(poems).T

# %%
df['author_id'] = df['author'].apply(lambda x: x['id'])
df['author_name'] = df['author'].apply(lambda x: x['name'])

df = df.drop(columns=['author'])

# %%
df['content'] = df['content'].apply(lambda x: x.replace('ӏ', 'I'))
df['content_len'] = df['content'].apply(lambda x: len(x))

# %%
import nltk

df['sentences'] = df['content'].apply(lambda x: nltk.sent_tokenize(x))
df['sentences_count'] = df['sentences'].apply(len)

# %%
df
# Out:
#         id                 title  \
# 3868  3868   Абрэдж Нухь и гъыбз
# 3867  3867         Абихъан иорэд
# 3866  3866  Абдзахэм язекӏо орэд
# 3865  3865        Ӏэдииху гъыбзэ
# 3864  3864           Ӏазэм иорэд
# ...    ...                   ...
# 9        9                   ОНО
# 8        8        КЪАПЛЪЭТ МЫДЭ!
# 7        7                  НАНЭ
# 6        6           ТХЬЭУСЫХАФЭ
# 5        5            ПСЫ ЦӀЫКӀУ
#
#                                                 content  author_id  \
# 3868  Абрэджы ныохэр зызэхэIыстхьакIэ ужъэгъуузы аIо...         99
# 3867  Сэхътэн цуакъэхэри тэпаплъ, оо…\r\nУихъани плъ...         99
# 3866  Абадзэхэр къумбылымэ щэхасэ гущэба,\r\nЖьыу: Е...         99
# 3865  И чэзумэ дыщынэсым, (ар) си Iэдииху \r\nЛъэс п...         99
# 3864  (Уэр), штаукIэу шъхьалымэ, \r\n(Уэр) зегъазэ, ...         99
# ...                                                 ...        ...
# 9     Ялъэгъуакъым псалъэ дахэм\nӀэм къимыщтэу илэжь...         81
# 8     «Русски горкэ» хужаIами\nФоупс IэфIуэ къысщыхъ...         81
# 7     Уэ пщIэрэ уи щIалэ цIыкIур\nХы Iуфэм щепэзэзэх...         81
# 6     Зи гуащIэр ин! Щхьэ сыбгъэщIа \nМураду щыIэм я...         88
# 5     Къум дэгу мэзыншэу губгъуэ джафэм \nИ псыпэр п...         88
#
#                author_name  content_len  \
# 3868       Зытхар тщӏэкъым         1492
# 3867       Зытхар тщӏэкъым         1103
# 3866       Зытхар тщӏэкъым          850
# 3865       Зытхар тщӏэкъым         1516
# 3864       Зытхар тщӏэкъым          502
# ...                    ...          ...
# 9        Щоджэнцӏыкӏу Алий          826
# 8        Щоджэнцӏыкӏу Алий         1017
# 7        Щоджэнцӏыкӏу Алий          985
# 6     Къуэдзокъуэ Лэкъумэн          902
# 5     Къуэдзокъуэ Лэкъумэн          736
#
#                                               sentences  sentences_count
# 3868  [Абрэджы ныохэр зызэхэIыстхьакIэ ужъэгъуузы аI...                9
# 3867  [Сэхътэн цуакъэхэри тэпаплъ, оо…\r\nУихъани пл...                9
# 3866  [Абадзэхэр къумбылымэ щэхасэ гущэба,\r\nЖьыу: ...               21
# 3865  [И чэзумэ дыщынэсым, (ар) си Iэдииху \r\nЛъэс ...               17
# 3864  [(Уэр), штаукIэу шъхьалымэ, \r\n(Уэр) зегъазэ,...                4
# ...                                                 ...              ...
# 9     [Ялъэгъуакъым псалъэ дахэм\nӀэм къимыщтэу илэж...               10
# 8     [«Русски горкэ» хужаIами\nФоупс IэфIуэ къысщых...                9
# 7     [Уэ пщIэрэ уи щIалэ цIыкIур\nХы Iуфэм щепэзэзэ...               11
# 6     [Зи гуащIэр ин!, Щхьэ сыбгъэщIа \nМураду щыIэм...               17
# 5     [Къум дэгу мэзыншэу губгъуэ джафэм \nИ псыпэр ...               11
#
# [3829 rows x 8 columns]

# %%
df
# Out:
#         id                 title  \
# 3868  3868   Абрэдж Нухь и гъыбз
# 3867  3867         Абихъан иорэд
# 3866  3866  Абдзахэм язекӏо орэд
# 3865  3865        Ӏэдииху гъыбзэ
# 3864  3864           Ӏазэм иорэд
# ...    ...                   ...
# 9        9                   ОНО
# 8        8        КЪАПЛЪЭТ МЫДЭ!
# 7        7                  НАНЭ
# 6        6           ТХЬЭУСЫХАФЭ
# 5        5            ПСЫ ЦӀЫКӀУ
#
#                                                 content  author_id  \
# 3868  Абрэджы ныохэр зызэхэIыстхьакIэ ужъэгъуузы аIо...         99
# 3867  Сэхътэн цуакъэхэри тэпаплъ, оо…\r\nУихъани плъ...         99
# 3866  Абадзэхэр къумбылымэ щэхасэ гущэба,\r\nЖьыу: Е...         99
# 3865  И чэзумэ дыщынэсым, (ар) си Iэдииху \r\nЛъэс п...         99
# 3864  (Уэр), штаукIэу шъхьалымэ, \r\n(Уэр) зегъазэ, ...         99
# ...                                                 ...        ...
# 9     Ялъэгъуакъым псалъэ дахэм\nӀэм къимыщтэу илэжь...         81
# 8     «Русски горкэ» хужаIами\nФоупс IэфIуэ къысщыхъ...         81
# 7     Уэ пщIэрэ уи щIалэ цIыкIур\nХы Iуфэм щепэзэзэх...         81
# 6     Зи гуащIэр ин! Щхьэ сыбгъэщIа \nМураду щыIэм я...         88
# 5     Къум дэгу мэзыншэу губгъуэ джафэм \nИ псыпэр п...         88
#
#                author_name  content_len  \
# 3868       Зытхар тщӏэкъым         1492
# 3867       Зытхар тщӏэкъым         1103
# 3866       Зытхар тщӏэкъым          850
# 3865       Зытхар тщӏэкъым         1516
# 3864       Зытхар тщӏэкъым          502
# ...                    ...          ...
# 9        Щоджэнцӏыкӏу Алий          826
# 8        Щоджэнцӏыкӏу Алий         1017
# 7        Щоджэнцӏыкӏу Алий          985
# 6     Къуэдзокъуэ Лэкъумэн          902
# 5     Къуэдзокъуэ Лэкъумэн          736
#
#                                               sentences  sentences_count
# 3868  [Абрэджы ныохэр зызэхэIыстхьакIэ ужъэгъуузы аI...                9
# 3867  [Сэхътэн цуакъэхэри тэпаплъ, оо…\r\nУихъани пл...                9
# 3866  [Абадзэхэр къумбылымэ щэхасэ гущэба,\r\nЖьыу: ...               21
# 3865  [И чэзумэ дыщынэсым, (ар) си Iэдииху \r\nЛъэс ...               17
# 3864  [(Уэр), штаукIэу шъхьалымэ, \r\n(Уэр) зегъазэ,...                4
# ...                                                 ...              ...
# 9     [Ялъэгъуакъым псалъэ дахэм\nӀэм къимыщтэу илэж...               10
# 8     [«Русски горкэ» хужаIами\nФоупс IэфIуэ къысщых...                9
# 7     [Уэ пщIэрэ уи щIалэ цIыкIур\nХы Iуфэм щепэзэзэ...               11
# 6     [Зи гуащIэр ин!, Щхьэ сыбгъэщIа \nМураду щыIэм...               17
# 5     [Къум дэгу мэзыншэу губгъуэ джафэм \nИ псыпэр ...               11
#
# [3829 rows x 8 columns]

# %%
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('./sbert_from_mlm_bert_8')

vectors = [
    model.encode(sent)
    for sent in tqdm(df['content'].tolist())
]
# Out:
# 100%|██████████| 3829/3829 [01:32<00:00, 41.29it/s]

# %%
from sklearn.cluster import AgglomerativeClustering
from collections import defaultdict


def get_clusters(vectors, n_clusters=20):
    agg_clustering = AgglomerativeClustering(n_clusters=n_clusters)
    labels = agg_clustering.fit_predict(vectors)
    return labels


def get_sents_by_clusters(words, labels):
    sents_by_clusters = defaultdict(list)
    for i, label in enumerate(labels):
        sents_by_clusters[label].append(words[i])

    return sents_by_clusters

# %%
n_clusters = 1000
labels = get_clusters(vectors, n_clusters=n_clusters)
sents_by_clusters = get_sents_by_clusters(df['id'], labels)
df['cluster'] = labels

for cluster_label, cluster_sents in sents_by_clusters.items():
    print(f'Cluster {cluster_label}:')
    print(cluster_sents)
    print()
# Out:
# Cluster 879:
# [3868, 3779]
#
# Cluster 991:
# [3867]
#
# Cluster 840:
# [3866]
#
# Cluster 394:
# [3865, 3687, 3145, 3074, 2831, 2480, 2230, 2181, 2166, 2164, 1552, 585, 66]
#
# Cluster 655:
# [3864]
#
# Cluster 374:
# [3863, 3247, 317]
#
# Cluster 720:
# [3862]
#
# Cluster 347:
# [3861, 3590, 2544]
#
# Cluster 193:
# [3860, 3500, 3425, 997, 910, 416, 408, 336, 329, 303]
#
# Cluster 311:
# [3859, 2455, 2391, 1893]
#
# Cluster 806:
# [3858]
#
# Cluster 319:
# [3857, 3563, 3316, 2071, 1102]
#
# Cluster 755:
# [3856, 2827, 1787, 1497, 1331, 691, 32]
#
# Cluster 86:
# [3855, 3736]
#
# Cluster 113:
# [3854, 318]
#
# Cluster 64:
# [3853, 2244, 1526, 1202, 644]
#
# Cluster 492:
# [3852, 3349, 2814, 2432, 1914, 687, 558, 465, 219]
#
# Cluster 307:
# [3851, 3256, 3197, 2642, 824, 194]
#
# Cluster 298:
# [3850, 1843, 943]
#
# Cluster 906:
# [3849]
#
# Cluster 30:
# [3848, 2890, 1676, 1156, 316]
#
# Cluster 826:
# [3847]
#
# Cluster 220:
# [3846, 3541, 1908, 1577, 1364]
#
# Cluster 93:
# [3845, 3006, 2961, 2926, 2348, 1269, 951, 759, 151]
#
# Cluster 340:
# [3844, 2397, 351]
#
# Cluster 522:
# [3843, 3782, 3165, 3025, 2704, 2443, 2074, 1966, 1231, 606, 16]
#
# Cluster 824:
# [3842]
#
# Cluster 645:
# [3841, 411]
#
# Cluster 1:
# [3840, 3181, 2222, 2162]
#
# Cluster 691:
# [3839, 3796, 145, 132]
#
# Cluster 300:
# [3838, 3783, 1317, 436, 370]
#
# Cluster 627:
# [3837, 3216, 2499, 2489, 2364, 1392, 734]
#
# Cluster 762:
# [3836, 387, 309]
#
# Cluster 985:
# [3835]
#
# Cluster 910:
# [3834, 3618, 1237, 1065, 1037, 918]
#
# Cluster 731:
# [3833]
#
# Cluster 345:
# [3832, 3750]
#
# Cluster 278:
# [3831, 3308, 2667, 2498, 2442, 2145, 1986, 1958, 1851, 1430, 534, 15]
#
# Cluster 448:
# [3830, 3703, 360, 139]
#
# Cluster 71:
# [3829, 1765, 1637, 1369]
#
# Cluster 202:
# [3828, 3437, 3272, 2639, 2625, 2470]
#
# Cluster 847:
# [3827]
#
# Cluster 247:
# [3826, 3452, 976]
#
# Cluster 75:
# [3825, 589]
#
# Cluster 288:
# [3824, 3605, 3516, 3354, 3071, 2644, 1941, 1728, 1433, 321, 83, 69]
#
# Cluster 839:
# [3823]
#
# Cluster 970:
# [3822]
#
# Cluster 967:
# [3821]
#
# Cluster 45:
# [3820, 3299, 3238, 3185, 2548, 1828, 1169, 1062, 948, 923, 434]
#
# Cluster 533:
# [3819, 1478]
#
# Cluster 49:
# [3818, 3603, 3078, 1968, 1095]
#
# Cluster 988:
# [3817]
#
# Cluster 424:
# [3816, 3798, 3375]
#
# Cluster 138:
# [3815, 2552]
#
# Cluster 302:
# [3814, 3066, 2993, 2860, 2721, 2689, 1682, 827]
#
# Cluster 756:
# [3813, 1265, 386]
#
# Cluster 828:
# [3812, 2268, 1852, 1049, 748]
#
# Cluster 55:
# [3811, 3739]
#
# Cluster 479:
# [3810, 3461, 3193, 190]
#
# Cluster 556:
# [3809, 2023]
#
# Cluster 801:
# [3808, 3492, 2579, 2082, 1854, 1836, 1617]
#
# Cluster 532:
# [3807]
#
# Cluster 255:
# [3806, 3184, 2744, 2686, 2375, 1611, 1602, 1258, 678]
#
# Cluster 579:
# [3805, 332]
#
# Cluster 489:
# [3804, 2379, 1963, 94]
#
# Cluster 439:
# [3803, 3276, 3232, 2284, 987, 668, 210]
#
# Cluster 169:
# [3802, 2620, 1268, 484]
#
# Cluster 427:
# [3801, 3639, 259]
#
# Cluster 373:
# [3800, 3141, 2914, 2841, 2832, 2823, 2716, 2621, 1261, 1052, 821, 794, 200, 177]
#
# Cluster 542:
# [3799, 368]
#
# Cluster 704:
# [3797, 3206, 3092, 3022, 2933, 2369, 2228, 1996, 1293, 725, 57, 13]
#
# Cluster 761:
# [3795, 3453, 363]
#
# Cluster 141:
# [3794, 3701, 3662, 3586, 3387, 3084, 3035, 2404, 1527, 1492, 1395, 1378, 548]
#
# Cluster 285:
# [3793, 2543, 2319, 1742, 1718, 1494, 1349]
#
# Cluster 730:
# [3792, 3660, 1691, 1543, 366]
#
# Cluster 318:
# [3791, 3196, 2616, 1406, 1058, 369]
#
# Cluster 457:
# [3790, 1170, 945]
#
# Cluster 47:
# [3789, 3329, 3211, 3064, 2756, 2475, 2110, 1299, 294, 273]
#
# Cluster 359:
# [3788, 1903, 1456, 1004]
#
# Cluster 657:
# [3787, 3244, 2196, 1746, 1662]
#
# Cluster 31:
# [3786, 3377]
#
# Cluster 569:
# [3785, 2097, 1917]
#
# Cluster 176:
# [3784, 3582, 3379, 3281, 3199, 2963, 2764, 2203, 1902, 1405, 1134, 1116, 1051, 994, 797, 515, 203, 131, 70]
#
# Cluster 528:
# [3781]
#
# Cluster 74:
# [3780, 3473, 331]
#
# Cluster 236:
# [3778, 272]
#
# Cluster 123:
# [3777, 3547, 3502, 2699, 2617, 1960, 1763, 1414, 1409, 1151, 840, 247, 148]
#
# Cluster 0:
# [3776, 3762, 3642, 3531, 3327, 3149, 3049, 2755, 2715, 2657, 2325, 2159, 1841, 1586, 1281, 757, 616, 485]
#
# Cluster 80:
# [3775, 2143, 1439, 1411, 1132]
#
# Cluster 34:
# [3774, 1323]
#
# Cluster 789:
# [3773]
#
# Cluster 420:
# [3772, 3647, 3367, 2825, 2640, 2328, 1424, 1274]
#
# Cluster 843:
# [3771]
#
# Cluster 143:
# [3770, 1794, 1622, 1376]
#
# Cluster 317:
# [3769, 3396, 1194, 333]
#
# Cluster 381:
# [3768, 1319, 1091, 372]
#
# Cluster 139:
# [3767, 3273, 2808, 1928, 1106, 798, 482, 433]
#
# Cluster 12:
# [3766, 1380, 1360, 1159, 970]
#
# Cluster 474:
# [3765, 3526]
#
# Cluster 919:
# [3764]
#
# Cluster 646:
# [3763, 2147, 493]
#
# Cluster 78:
# [3761, 397, 362]
#
# Cluster 470:
# [3760, 1727]
#
# Cluster 260:
# [3759, 1390]
#
# Cluster 400:
# [3758, 3613, 2884, 1710, 1574, 1016, 483]
#
# Cluster 605:
# [3757]
#
# Cluster 996:
# [3756, 3266, 2848]
#
# Cluster 222:
# [3755, 3368]
#
# Cluster 38:
# [3754, 3063, 1994]
#
# Cluster 315:
# [3753, 3515, 3471, 2592, 1107, 236, 84, 75]
#
# Cluster 131:
# [3752, 3507]
#
# Cluster 73:
# [3751, 2672, 1719, 158]
#
# Cluster 146:
# [3749, 3554, 3178, 1085, 280]
#
# Cluster 912:
# [3748]
#
# Cluster 783:
# [3747]
#
# Cluster 325:
# [3746, 3236]
#
# Cluster 50:
# [3745, 3501, 3469, 3113, 3004, 2453, 1947, 1901, 1831, 1822, 979, 889, 769, 666, 613, 142, 122, 117]
#
# Cluster 286:
# [3744, 3011, 591]
#
# Cluster 555:
# [3743, 1876]
#
# Cluster 63:
# [3742, 2821, 1720, 1418, 1086, 1027, 440]
#
# Cluster 228:
# [3741, 3707, 2327, 1490, 1421, 1254, 1035, 409]
#
# Cluster 281:
# [3740, 1028, 957]
#
# Cluster 36:
# [3738, 3722, 3369, 3021, 2750, 2209, 1729, 1534, 1475, 1441, 580, 439, 20]
#
# Cluster 426:
# [3737, 1949, 1784, 842]
#
# Cluster 644:
# [3735, 106]
#
# Cluster 333:
# [3734, 1276]
#
# Cluster 414:
# [3733, 2633]
#
# Cluster 911:
# [3732, 1563, 1185, 689]
#
# Cluster 937:
# [3731]
#
# Cluster 65:
# [3730, 1094, 379]
#
# Cluster 397:
# [3729, 3489, 2234, 2038, 648]
#
# Cluster 129:
# [3728, 3505, 3146, 3106, 2869, 2250, 1172, 1125, 820, 193]
#
# Cluster 450:
# [3727, 3661]
#
# Cluster 608:
# [3726, 3564]
#
# Cluster 573:
# [3725]
#
# Cluster 519:
# [3724, 3169, 3168, 2468, 941, 90, 64]
#
# Cluster 174:
# [3723, 1880, 1386]
#
# Cluster 19:
# [3721, 3134, 3105, 3015, 2960, 2953, 2826, 2809, 2778, 2766, 2650, 1093, 1061, 992]
#
# Cluster 421:
# [3720, 3180, 2533, 2183, 1428]
#
# Cluster 965:
# [3719]
#
# Cluster 917:
# [3718, 2165, 841]
#
# Cluster 485:
# [3717, 1118]
#
# Cluster 946:
# [3716, 3455, 267]
#
# Cluster 128:
# [3715, 3607, 2053]
#
# Cluster 635:
# [3714, 3573, 3508, 3439, 2795, 2135, 1885, 1677, 1235, 1229, 1152, 1100, 1059]
#
# Cluster 115:
# [3713, 1874]
#
# Cluster 227:
# [3712, 3459, 2819, 1980, 1853, 1467, 1463, 1451, 1442, 1431, 1301, 1002, 912, 635, 432]
#
# Cluster 112:
# [3711, 3553, 3268, 2952, 2584, 1982, 1927, 1034, 412, 137]
#
# Cluster 54:
# [3710, 3548, 3263, 2873, 2133, 536]
#
# Cluster 483:
# [3709, 3381, 3357, 3090, 2654, 2156, 975]
#
# Cluster 121:
# [3708, 3333, 3157, 2720, 2537, 2272, 1965, 1935, 832]
#
# Cluster 467:
# [3706, 3449, 3052, 2486, 2079, 985]
#
# Cluster 454:
# [3705, 2958, 2263, 1547, 415, 400]
#
# Cluster 563:
# [3704, 1929]
#
# Cluster 191:
# [3702, 3591, 3344, 3296, 1981, 1708, 1464, 1249, 1071, 878, 809]
#
# Cluster 69:
# [3700, 3543, 3051, 3032, 2604, 2392, 2137, 1801, 1101, 1040, 924, 799, 650, 505, 279, 108]
#
# Cluster 941:
# [3699, 1200]
#
# Cluster 229:
# [3698, 1905, 1568, 1322, 1312]
#
# Cluster 226:
# [3697, 3584, 3318, 3257, 2637, 2408, 1898, 1734, 1521, 1502, 1403, 1207, 1001, 993, 188]
#
# Cluster 796:
# [3696, 2516, 2481]
#
# Cluster 927:
# [3695]
#
# Cluster 628:
# [3694, 1594, 1139]
#
# Cluster 726:
# [3693, 1556]
#
# Cluster 294:
# [3692, 3637, 3260, 3189, 1878, 1443]
#
# Cluster 178:
# [3691, 3565, 1715, 991]
#
# Cluster 787:
# [3690, 902, 718]
#
# Cluster 491:
# [3689, 3599, 3301, 2714]
#
# Cluster 564:
# [3688]
#
# Cluster 107:
# [3686, 3666, 1769, 1525, 625]
#
# Cluster 166:
# [3685, 3395, 2050, 1899, 1760, 1647]
#
# Cluster 205:
# [3684, 3551, 3069, 3061, 2271, 2056, 1029, 804, 222, 112]
#
# Cluster 795:
# [3683, 3665, 2569, 1606, 773]
#
# Cluster 975:
# [3682]
#
# Cluster 344:
# [3681, 3659, 3341, 3297, 2879, 2846, 2830, 2550, 2493, 2415, 2068, 1940, 1815, 1302, 1136, 852, 704, 28, 6]
#
# Cluster 270:
# [3680, 770, 199]
#
# Cluster 706:
# [3679, 2951, 2784, 1663, 1326, 702]
#
# Cluster 261:
# [3678, 2124]
#
# Cluster 98:
# [3677, 3467, 3322, 3283, 3107, 2948, 2887, 2836, 2746, 2608, 2265, 2140, 1642, 1609, 1446, 664, 618, 562]
#
# Cluster 810:
# [3676, 270]
#
# Cluster 219:
# [3675, 2956, 2598, 622, 179]
#
# Cluster 425:
# [3674, 3669]
#
# Cluster 360:
# [3673, 3628, 3343, 3042, 2985, 2803, 2752, 2740, 2719, 1599]
#
# Cluster 355:
# [3672, 3003, 2760]
#
# Cluster 434:
# [3671, 2248, 937]
#
# Cluster 591:
# [3670, 2799, 2478]
#
# Cluster 422:
# [3668, 1721, 617, 602]
#
# Cluster 962:
# [3667, 982, 776, 529]
#
# Cluster 327:
# [3664, 3464, 3356, 3155, 1950, 1536, 1336, 800]
#
# Cluster 779:
# [3663, 3626]
#
# Cluster 312:
# [3658, 2261, 95]
#
# Cluster 956:
# [3657, 3154, 2652, 2523, 2504, 2463, 2462]
#
# Cluster 81:
# [3656, 2655, 1244, 1115]
#
# Cluster 182:
# [3655, 3414, 3383, 3275, 3013, 3002, 2934, 2587, 2258, 2013, 1610, 1592, 1011, 575]
#
# Cluster 67:
# [3654, 3557, 3546, 3115, 3029, 2975, 2813, 2771, 2770, 2762, 2700, 2676, 2330, 2274, 1855, 1692, 1243, 1179, 1149, 1099, 921, 869]
#
# Cluster 108:
# [3653, 3081, 2998, 2880, 2822, 1861, 1551, 986]
#
# Cluster 516:
# [3652, 3087, 2561, 2520, 2509, 2459, 1807, 56]
#
# Cluster 320:
# [3651, 3242, 3101, 3041, 2786, 2737, 1575, 537, 488, 187, 86, 79]
#
# Cluster 982:
# [3650]
#
# Cluster 942:
# [3649, 2116]
#
# Cluster 643:
# [3648, 3631, 3328, 3142, 1165, 939, 667]
#
# Cluster 189:
# [3646, 3527, 2242, 2161, 1137]
#
# Cluster 221:
# [3645, 3210, 3068, 2927, 2101, 1860, 838, 626, 68]
#
# Cluster 342:
# [3644, 2233]
#
# Cluster 72:
# [3643, 623]
#
# Cluster 583:
# [3641, 346]
#
# Cluster 167:
# [3640, 3372, 2893, 2482, 2119, 1420, 700, 284, 162]
#
# Cluster 8:
# [3638, 2812, 2797, 2776, 2724, 2428, 2028, 1712, 1283, 1232, 810, 258, 224]
#
# Cluster 343:
# [3636, 1201]
#
# Cluster 961:
# [3635]
#
# Cluster 304:
# [3634, 1558, 1374]
#
# Cluster 378:
# [3633, 3270, 3026, 1144, 758, 755, 479, 451]
#
# Cluster 631:
# [3632]
#
# Cluster 781:
# [3630, 2335]
#
# Cluster 87:
# [3629, 3535, 3518, 3374, 2983, 2969, 2941, 2923, 2739, 2734, 2733, 2345, 2246, 2218, 2202, 1415, 1117, 1013, 961, 946, 860, 676, 523, 404, 110]
#
# Cluster 496:
# [3627, 1480]
#
# Cluster 201:
# [3625, 3373, 3012, 2390, 1155, 828, 812]
#
# Cluster 194:
# [3624, 2789, 2449, 780, 26]
#
# Cluster 106:
# [3623, 2796, 1367, 1353]
#
# Cluster 723:
# [3622]
#
# Cluster 606:
# [3621, 2888]
#
# Cluster 249:
# [3620, 2409, 2186, 1809, 1803, 1772, 1429]
#
# Cluster 814:
# [3619, 2103, 627]
#
# Cluster 23:
# [3617, 3442, 3429, 2121, 1362, 662]
#
# Cluster 292:
# [3616, 3320, 3246, 2378, 2376, 2264, 1818, 1580, 1387, 1215, 282]
#
# Cluster 550:
# [3615, 2779, 2526, 2396, 1890, 1869, 1785, 1672, 1000, 467]
#
# Cluster 501:
# [3614, 3598, 3359, 3200, 3171, 2456, 1939, 1800, 1799, 1535, 1334, 709, 657, 114]
#
# Cluster 334:
# [3612, 3608, 3562, 2794, 1550, 1183, 935, 803, 119]
#
# Cluster 356:
# [3611, 2309, 1393, 339]
#
# Cluster 157:
# [3610, 2876]
#
# Cluster 258:
# [3609, 2670, 2207, 2167, 1675, 1641, 1357, 1327, 938, 428, 395]
#
# Cluster 462:
# [3606, 3114, 3083, 2384]
#
# Cluster 848:
# [3604, 2922, 2351]
#
# Cluster 83:
# [3602, 3098, 2946, 1315, 1308, 570]
#
# Cluster 672:
# [3601, 2347]
#
# Cluster 387:
# [3600, 3172, 1997, 1700, 1389, 1284, 286, 235]
#
# Cluster 895:
# [3597]
#
# Cluster 816:
# [3596]
#
# Cluster 969:
# [3595]
#
# Cluster 11:
# [3594, 3447, 3009, 2938, 2632, 2158, 1509, 1343, 849, 692, 174, 141]
#
# Cluster 218:
# [3593, 2743]
#
# Cluster 647:
# [3592, 811, 572]
#
# Cluster 253:
# [3589, 1607]
#
# Cluster 792:
# [3588, 3264, 1819, 1277]
#
# Cluster 791:
# [3587, 3118, 1298, 672]
#
# Cluster 524:
# [3585, 2851, 2532, 710, 640]
#
# Cluster 322:
# [3583, 2895, 2839, 2660, 2385, 2314, 2255, 1973, 1832, 1748, 1747, 1701, 1566, 1448, 1373, 1286, 1210, 1081, 837, 496, 324, 251, 240, 185]
#
# Cluster 296:
# [3581, 3570, 1541, 679]
#
# Cluster 390:
# [3580, 2935, 2915, 2538, 2077, 847]
#
# Cluster 585:
# [3579, 3399, 3378, 3254, 2861, 2431, 2304, 1685, 1489, 1310, 1176, 1083, 206]
#
# Cluster 487:
# [3578, 2713, 2229]
#
# Cluster 149:
# [3577, 3389, 3348, 3290, 3138, 2467, 2370, 2142, 1984, 1220, 566, 538]
#
# Cluster 905:
# [3576, 1598, 1573]
#
# Cluster 944:
# [3575, 3234, 2728, 1839, 968, 765, 24]
#
# Cluster 945:
# [3574, 2414, 1520]
#
# Cluster 313:
# [3572, 3523, 2574]
#
# Cluster 890:
# [3571, 2556, 1226]
#
# Cluster 352:
# [3569, 3504, 3485, 2276, 468]
#
# Cluster 688:
# [3568, 2087]
#
# Cluster 815:
# [3567, 643]
#
# Cluster 876:
# [3566, 3533, 3186, 2999, 2973, 2971, 2913, 2710, 1595]
#
# Cluster 833:
# [3561, 3227, 2675, 2044, 1694, 1361, 753, 238]
#
# Cluster 653:
# [3560, 3284, 2729, 2693, 1240, 1175, 1123, 859, 833]
#
# Cluster 547:
# [3559, 3014, 2816]
#
# Cluster 934:
# [3558]
#
# Cluster 101:
# [3556, 2978, 2957, 2856, 2591, 1213, 588]
#
# Cluster 305:
# [3555, 693, 11]
#
# Cluster 170:
# [3552, 3250, 2897, 2691, 2679, 2576, 2454, 2185, 1988, 1936, 1665, 1466, 1397, 1174, 1019, 547]
#
# Cluster 185:
# [3550, 1279, 470]
#
# Cluster 84:
# [3549, 3203, 3137, 3024, 2870, 2732, 2662, 2611, 1626, 1618, 1217, 1150, 1043, 932, 156, 82, 80, 10]
#
# Cluster 103:
# [3545, 3143]
#
# Cluster 95:
# [3544, 684, 477]
#
# Cluster 574:
# [3542, 2446, 2434, 681, 19]
#
# Cluster 190:
# [3540, 969, 396]
#
# Cluster 482:
# [3539, 3100, 1180]
#
# Cluster 864:
# [3538, 2524]
#
# Cluster 210:
# [3537, 2452, 29]
#
# Cluster 623:
# [3536]
#
# Cluster 76:
# [3534, 3456, 2680, 2424, 2413, 2388, 2332, 1978, 1866, 1290]
#
# Cluster 907:
# [3532, 3259, 2745, 2495, 2419, 2366, 2299, 2294, 2002, 1907, 1891, 454]
#
# Cluster 529:
# [3530, 3463]
#
# Cluster 295:
# [3529, 1882, 1755, 1148]
#
# Cluster 130:
# [3528, 3226, 2109, 557]
#
# Cluster 136:
# [3525, 3480, 3403, 3109, 3099, 3001, 2664, 2610, 2464, 2173, 2070, 1711, 1500, 1491, 1394, 844, 474, 230, 165]
#
# Cluster 256:
# [3524, 3237, 2012, 1919, 1670, 1436, 1211, 908, 461, 417, 140, 126]
#
# Cluster 132:
# [3522, 2310]
#
# Cluster 846:
# [3521, 2466, 1440, 1300, 1154, 1087, 682]
#
# Cluster 590:
# [3520, 2792, 2476, 1529, 464]
#
# Cluster 857:
# [3519, 3233, 2790, 2671, 2099, 2011, 1620, 1282, 814, 778, 688, 452]
#
# Cluster 196:
# [3517, 1133, 1097, 1096, 1060, 956]
#
# Cluster 348:
# [3514, 2300, 2153, 1859, 1752, 1038, 456, 115]
#
# Cluster 126:
# [3513, 3416, 3121, 2707, 2703, 2701, 2683, 2410, 2367, 2144, 2111, 2095, 1042, 1024, 896, 829, 771]
#
# Cluster 24:
# [3512, 3077, 3036, 2706, 2484, 2130, 2052, 1937, 1407, 1404, 754, 23]
#
# Cluster 5:
# [3511, 1895, 1656, 1638, 1623, 1285, 1030, 785, 430, 380, 147]
#
# Cluster 94:
# [3510, 1732, 1619, 1614, 900, 121]
#
# Cluster 874:
# [3509]
#
# Cluster 727:
# [3506, 3404, 3010, 2777, 2010, 1781, 904]
#
# Cluster 610:
# [3503]
#
# Cluster 3:
# [3499, 3440, 3394, 2904, 2546, 2399, 1621, 984, 690, 157]
#
# Cluster 122:
# [3498, 3405, 2911, 2908, 2759, 2566, 1817, 1365, 1351, 995, 875, 807, 656, 632, 574]
#
# Cluster 603:
# [3497, 3201, 2278, 2129, 1925, 884]
#
# Cluster 978:
# [3496, 705]
#
# Cluster 37:
# [3495, 2659, 2607, 1922, 1005, 250]
#
# Cluster 891:
# [3494]
#
# Cluster 957:
# [3493]
#
# Cluster 943:
# [3491, 3102, 1884, 817, 545]
#
# Cluster 855:
# [3490, 2356]
#
# Cluster 4:
# [3488, 3393, 1654]
#
# Cluster 698:
# [3487, 2032]
#
# Cluster 207:
# [3486, 1967, 646]
#
# Cluster 200:
# [3484, 1627, 745, 441]
#
# Cluster 468:
# [3483, 315]
#
# Cluster 709:
# [3482]
#
# Cluster 264:
# [3481, 3050, 2916, 2036]
#
# Cluster 641:
# [3479, 928, 699]
#
# Cluster 145:
# [3478, 3361, 3330, 2930, 2735, 2179, 2151, 2114, 1771, 1481, 1391, 1356, 1355, 777]
#
# Cluster 262:
# [3477, 376]
#
# Cluster 652:
# [3476, 2402]
#
# Cluster 290:
# [3475, 940]
#
# Cluster 661:
# [3474]
#
# Cluster 335:
# [3472, 498]
#
# Cluster 274:
# [3470, 3070, 3016, 2990, 2793, 2782, 2774, 2741, 2682, 2172, 2123, 1989, 1805, 1770, 1503, 1221, 1066, 866, 835, 552, 354]
#
# Cluster 172:
# [3468, 3424, 2236, 300]
#
# Cluster 61:
# [3466, 3434, 3427, 3420, 2751, 2580, 1948, 1674, 1033, 155]
#
# Cluster 525:
# [3465, 2709, 2577, 2157, 796, 513, 186]
#
# Cluster 576:
# [3462]
#
# Cluster 805:
# [3460, 1894, 1865, 1064, 383]
#
# Cluster 96:
# [3458, 3454, 3435, 3311, 2931, 2843, 2282, 1280, 1076]
#
# Cluster 245:
# [3457, 2943, 2677, 1971, 1462, 242]
#
# Cluster 399:
# [3451, 1075, 958]
#
# Cluster 446:
# [3450, 3108, 2098]
#
# Cluster 243:
# [3448, 3391, 1146]
#
# Cluster 291:
# [3446, 2359]
#
# Cluster 99:
# [3445, 2599, 2270, 2083, 1827, 1738, 1544, 516, 201]
#
# Cluster 410:
# [3444, 3358, 3332, 1458, 248]
#
# Cluster 283:
# [3443, 135]
#
# Cluster 111:
# [3441, 2361]
#
# Cluster 14:
# [3438, 3151, 1931, 1892, 1073]
#
# Cluster 367:
# [3436, 3342, 3158, 2979, 2962, 2877, 2260, 1423]
#
# Cluster 323:
# [3433, 1080]
#
# Cluster 739:
# [3432, 2605, 1120]
#
# Cluster 844:
# [3431, 3076]
#
# Cluster 192:
# [3430, 3408, 92]
#
# Cluster 811:
# [3428, 2235, 686]
#
# Cluster 768:
# [3426, 851, 475, 307]
#
# Cluster 158:
# [3423, 3267, 3147, 3082, 2857, 2765, 2497, 1709, 1270, 87]
#
# Cluster 724:
# [3422, 1057]
#
# Cluster 153:
# [3421, 2485, 2437, 2139, 1823, 661, 101]
#
# Cluster 377:
# [3419, 1744, 1587, 1368, 1340, 813]
#
# Cluster 869:
# [3418]
#
# Cluster 750:
# [3417]
#
# Cluster 618:
# [3415, 2626]
#
# Cluster 699:
# [3413, 2875, 2515, 2051, 1512, 846, 556, 540, 150]
#
# Cluster 733:
# [3412, 1553, 1140]
#
# Cluster 972:
# [3411]
#
# Cluster 803:
# [3410]
#
# Cluster 777:
# [3409, 78]
#
# Cluster 402:
# [3407, 2338, 2297, 330]
#
# Cluster 683:
# [3406, 301]
#
# Cluster 742:
# [3402, 2549]
#
# Cluster 845:
# [3401, 2811, 1873, 202]
#
# Cluster 666:
# [3400]
#
# Cluster 77:
# [3398, 3034, 2738, 2418, 2412, 1762, 1703, 1579, 1214, 605, 472, 453, 343, 245, 168, 102]
#
# Cluster 714:
# [3397]
#
# Cluster 213:
# [3392, 2849, 1114, 645]
#
# Cluster 282:
# [3390, 1816, 1321]
#
# Cluster 237:
# [3388, 2865, 1505, 883, 658, 655]
#
# Cluster 520:
# [3386, 1332]
#
# Cluster 199:
# [3385, 1538, 437]
#
# Cluster 769:
# [3384, 2997, 2892, 2636, 2372, 2201, 1495, 1111]
#
# Cluster 984:
# [3382, 3324, 916]
#
# Cluster 416:
# [3380, 2349, 1766]
#
# Cluster 719:
# [3376, 2551]
#
# Cluster 476:
# [3371, 1304]
#
# Cluster 959:
# [3370]
#
# Cluster 100:
# [3366, 3339, 2253, 1562, 1018, 737, 499]
#
# Cluster 558:
# [3365, 3153, 3111, 3067, 1352]
#
# Cluster 851:
# [3364, 1482, 1459, 1271, 895, 738, 375, 252]
#
# Cluster 455:
# [3363, 2465]
#
# Cluster 104:
# [3362, 2303, 1590, 1539]
#
# Cluster 51:
# [3360, 3255, 2473]
#
# Cluster 362:
# [3355, 3043, 2564, 2037, 1050]
#
# Cluster 42:
# [3353, 2937, 1157, 721]
#
# Cluster 276:
# [3352, 3164, 2590, 2254, 212, 169, 167, 164, 129]
#
# Cluster 549:
# [3351, 3294, 2666, 2163, 1870, 1767, 947, 836, 766]
#
# Cluster 151:
# [3350, 2045, 791]
#
# Cluster 617:
# [3347, 3280, 1514, 673]
#
# Cluster 159:
# [3346, 2578, 2134]
#
# Cluster 269:
# [3345, 3219, 3110, 3044, 871]
#
# Cluster 297:
# [3340, 2996, 2275, 1840, 1253, 296]
#
# Cluster 587:
# [3338, 2866, 2658, 2239, 1993, 1956, 1465, 1452, 1371, 805]
#
# Cluster 570:
# [3337, 3292, 3131, 2194, 1862]
#
# Cluster 250:
# [3336, 3129, 1930, 823, 750, 107]
#
# Cluster 212:
# [3335, 2575, 2337, 2214, 1684, 1354, 1348, 1187, 1103, 815, 522]
#
# Cluster 10:
# [3334, 3148, 2125, 610, 584]
#
# Cluster 881:
# [3331]
#
# Cluster 808:
# [3326, 1724, 1633, 905, 512]
#
# Cluster 162:
# [3325, 3072, 2696, 2678, 2674, 2529, 2386, 2007, 1953, 1863, 1730, 1158, 933, 567, 243]
#
# Cluster 682:
# [3323, 3209, 2912, 2371, 1524, 1119, 864, 701]
#
# Cluster 539:
# [3321, 2783, 2698, 2653, 2363, 1740, 1737, 1705, 1485, 670, 551, 460, 105]
#
# Cluster 354:
# [3319, 3161, 2669, 2216, 1696, 1517, 735, 669]
#
# Cluster 165:
# [3317, 3007, 2989, 2807, 2785, 2736, 2627, 2075, 1924, 949, 834, 749, 740, 685, 514]
#
# Cluster 25:
# [3315, 1079, 291]
#
# Cluster 948:
# [3314, 3277, 3086, 1714, 808, 490]
#
# Cluster 208:
# [3312, 925]
#
# Cluster 309:
# [3310, 3262, 1739]
#
# Cluster 668:
# [3309, 3117, 2518, 1970, 1247, 98]
#
# Cluster 650:
# [3307]
#
# Cluster 364:
# [3306, 3214, 2406, 1793, 1206, 907]
#
# Cluster 27:
# [3305, 1203]
#
# Cluster 415:
# [3304, 2568, 1856, 870, 706]
#
# Cluster 209:
# [3303, 2531, 1743, 1278, 239, 221]
#
# Cluster 902:
# [3302, 563]
#
# Cluster 613:
# [3300, 1153]
#
# Cluster 604:
# [3298]
#
# Cluster 204:
# [3295, 1972, 1474]
#
# Cluster 351:
# [3293, 3287, 3278, 2977, 2622, 1516, 731, 609, 603, 14]
#
# Cluster 507:
# [3291, 2394, 2078, 1911]
#
# Cluster 545:
# [3289, 3093]
#
# Cluster 511:
# [3288, 3005, 2798, 2781, 1408]
#
# Cluster 594:
# [3286]
#
# Cluster 259:
# [3285, 3240, 3224, 3033, 2131, 1754, 1745, 1699, 1471, 410]
#
# Cluster 127:
# [3282, 2479, 872]
#
# Cluster 357:
# [3279, 3140, 1797]
#
# Cluster 206:
# [3274, 3122, 3119, 3065, 2154, 1717, 1110, 535]
#
# Cluster 46:
# [3271, 565]
#
# Cluster 807:
# [3269]
#
# Cluster 469:
# [3265, 2033, 1995, 1704, 892]
#
# Cluster 137:
# [3261, 2560, 2362]
#
# Cluster 776:
# [3258]
#
# Cluster 841:
# [3253]
#
# Cluster 316:
# [3252, 3205, 3103, 2688, 2629, 2488, 1569, 1476, 480]
#
# Cluster 179:
# [3251, 3060, 2558, 2491, 1916, 1379, 683, 163]
#
# Cluster 242:
# [3249, 3159, 2619, 1145]
#
# Cluster 405:
# [3248, 2871, 2267, 2182, 1555, 1370]
#
# Cluster 712:
# [3245, 2980, 2810, 2547, 1632]
#
# Cluster 241:
# [3243, 2257, 1943, 1926, 1007, 506, 175]
#
# Cluster 748:
# [3241, 3222, 2942, 2891, 1499, 746, 665, 636, 382, 134, 74]
#
# Cluster 266:
# [3239, 1679]
#
# Cluster 580:
# [3235, 1786, 1416, 654]
#
# Cluster 751:
# [3231, 1975, 125]
#
# Cluster 120:
# [3230, 1683]
#
# Cluster 952:
# [3229, 2804, 2628, 1664, 927]
#
# Cluster 546:
# [3228, 2232]
#
# Cluster 780:
# [3225, 2727, 2088, 2046, 1591, 1487, 880]
#
# Cluster 203:
# [3223, 3075, 990, 27]
#
# Cluster 273:
# [3221, 2968, 2094, 1918, 1680, 822, 795, 160, 120]
#
# Cluster 134:
# [3220, 1806, 873, 747]
#
# Cluster 85:
# [3218, 2040, 1998]
#
# Cluster 850:
# [3217, 1820, 1751, 1671, 1496, 1417, 714, 555]
#
# Cluster 21:
# [3215, 2730, 2340, 1230, 8]
#
# Cluster 509:
# [3213, 3056, 2333, 1992, 1954, 1384, 553, 526]
#
# Cluster 503:
# [3212, 2238, 1567]
#
# Cluster 2:
# [3208, 2450, 276]
#
# Cluster 231:
# [3207, 1542]
#
# Cluster 371:
# [3204, 2353]
#
# Cluster 747:
# [3202, 891]
#
# Cluster 395:
# [3198, 2490, 1425, 751, 729]
#
# Cluster 667:
# [3195, 3167, 2150, 2073, 209]
#
# Cluster 903:
# [3194]
#
# Cluster 721:
# [3192, 2850, 2711, 2054]
#
# Cluster 417:
# [3191, 2947, 2919, 2708, 2438, 2266, 2200, 2138, 1112, 1026]
#
# Cluster 535:
# [3190, 2702, 2323, 2115, 2108, 1796, 1056, 299, 249, 111, 59]
#
# Cluster 757:
# [3188]
#
# Cluster 411:
# [3187, 2597, 1910, 843, 561]
#
# Cluster 534:
# [3183, 2041, 124]
#
# Cluster 105:
# [3182, 1636, 423, 392]
#
# Cluster 251:
# [3179, 2136, 2039, 1848, 1716, 1039, 903]
#
# Cluster 445:
# [3177, 2534, 72]
#
# Cluster 868:
# [3176, 781]
#
# Cluster 163:
# [3175, 3174, 2780, 2573, 2104, 1236, 1131]
#
# Cluster 505:
# [3173, 1479, 733]
#
# Cluster 303:
# [3170, 1666, 577]
#
# Cluster 331:
# [3166, 2112]
#
# Cluster 447:
# [3163, 2542, 1913, 1650, 885, 568, 323, 181]
#
# Cluster 62:
# [3162, 3027, 2603, 225]
#
# Cluster 366:
# [3160, 2974, 1900, 153]
#
# Cluster 926:
# [3156, 2199, 1668, 825, 638, 564]
#
# Cluster 388:
# [3152, 2514, 2461]
#
# Cluster 118:
# [3150, 2645, 1192]
#
# Cluster 164:
# [3144, 2748, 2426, 2016, 1764, 955, 234]
#
# Cluster 224:
# [3139, 2277, 893]
#
# Cluster 915:
# [3136, 2440, 2249, 192]
#
# Cluster 252:
# [3135, 2864, 2638, 2069, 1625, 1468, 621, 594, 590]
#
# Cluster 235:
# [3133, 2316, 2155]
#
# Cluster 358:
# [3132, 1074]
#
# Cluster 508:
# [3130, 2342, 1189, 308]
#
# Cluster 494:
# [3128, 2723, 2090, 462, 241]
#
# Cluster 435:
# [3127, 2712]
#
# Cluster 324:
# [3126, 2886, 2373, 2301, 2058, 1649, 227, 226, 9]
#
# Cluster 499:
# [3125, 2987, 1906, 136]
#
# Cluster 940:
# [3124, 601, 487]
#
# Cluster 637:
# [3123, 1761, 1046, 1045]
#
# Cluster 554:
# [3120]
#
# Cluster 675:
# [3116, 2321]
#
# Cluster 442:
# [3112, 862]
#
# Cluster 389:
# [3104, 2507, 752, 427]
#
# Cluster 960:
# [3097]
#
# Cluster 188:
# [3096, 18]
#
# Cluster 233:
# [3095, 1834, 1272, 229, 189, 166]
#
# Cluster 363:
# [3094, 695]
#
# Cluster 279:
# [3091, 3088, 3031, 2874, 2681, 2416, 2380, 2285, 2132, 1951, 1842, 1808, 1055, 1017]
#
# Cluster 239:
# [3089, 2882, 2184, 1681, 1239, 863, 96]
#
# Cluster 215:
# [3085, 2441]
#
# Cluster 578:
# [3080, 3019, 2950, 2921, 2905, 2536, 2241, 2211, 2210, 1661, 1493, 818, 143]
#
# Cluster 35:
# [3079, 2624]
#
# Cluster 744:
# [3073, 1533, 1234, 517]
#
# Cluster 332:
# [3062, 2433, 1788, 1113]
#
# Cluster 620:
# [3059, 996, 495]
#
# Cluster 70:
# [3058, 2858, 2769, 2223, 2107, 1969, 868, 398, 298, 173, 113]
#
# Cluster 588:
# [3057, 1204]
#
# Cluster 633:
# [3055]
#
# Cluster 887:
# [3054]
#
# Cluster 938:
# [3053, 1564, 1109, 1032]
#
# Cluster 600:
# [3048]
#
# Cluster 301:
# [3047, 2901, 2835, 2306, 2096, 2048, 2034, 1897, 1857, 1372, 1292, 861, 819, 541, 159]
#
# Cluster 999:
# [3046, 2290, 761, 675, 510]
#
# Cluster 144:
# [3045, 1528, 1484]
#
# Cluster 981:
# [3040]
#
# Cluster 859:
# [3039]
#
# Cluster 513:
# [3038, 2302, 528, 211]
#
# Cluster 681:
# [3037, 2343, 2176, 1604, 1297, 599]
#
# Cluster 289:
# [3030, 1173]
#
# Cluster 995:
# [3028, 2646, 1054]
#
# Cluster 117:
# [3023, 2868, 2336, 571]
#
# Cluster 548:
# [3020, 2754, 2247, 1266, 707]
#
# Cluster 58:
# [3018, 2932, 2212, 936]
#
# Cluster 68:
# [3017, 2917, 2852, 2280, 1344]
#
# Cluster 700:
# [3008, 2840, 2171, 1673, 1275, 1218, 853, 711, 446, 196]
#
# Cluster 914:
# [3000, 2601]
#
# Cluster 852:
# [2995, 2411, 790, 455]
#
# Cluster 812:
# [2994, 2925, 116]
#
# Cluster 707:
# [2992, 2982, 1789]
#
# Cluster 431:
# [2991, 2903, 2286]
#
# Cluster 760:
# [2988, 2772, 2722, 2429, 1589]
#
# Cluster 161:
# [2986, 2355, 894, 48]
#
# Cluster 701:
# [2984, 2842, 2180, 1021, 831, 783, 716]
#
# Cluster 827:
# [2981]
#
# Cluster 865:
# [2976, 2900]
#
# Cluster 752:
# [2972, 2889]
#
# Cluster 171:
# [2970, 2894, 615]
#
# Cluster 738:
# [2967, 2966, 960, 897]
#
# Cluster 764:
# [2965]
#
# Cluster 109:
# [2964, 1812, 1585, 1557]
#
# Cluster 734:
# [2959, 2936, 1921, 1868, 950, 204, 5]
#
# Cluster 925:
# [2955, 2907, 530, 425]
#
# Cluster 214:
# [2954, 1887, 1628]
#
# Cluster 473:
# [2949, 2583, 1979, 1875, 1792, 802]
#
# Cluster 181:
# [2945, 2939, 2178, 1658, 1645, 786, 775, 554, 138]
#
# Cluster 849:
# [2944, 2906]
#
# Cluster 275:
# [2940, 2663, 2545, 1702, 1447, 1438, 1432, 877]
#
# Cluster 964:
# [2929, 2457, 2213, 1422, 128]
#
# Cluster 788:
# [2928, 788]
#
# Cluster 669:
# [2924, 2920, 2818]
#
# Cluster 702:
# [2918, 2582, 2208, 1757, 1008, 965, 463, 208]
#
# Cluster 471:
# [2910, 1582, 1359, 764, 63]
#
# Cluster 458:
# [2909, 1821, 1613, 195]
#
# Cluster 636:
# [2902, 1212, 858, 830]
#
# Cluster 778:
# [2899]
#
# Cluster 875:
# [2898]
#
# Cluster 437:
# [2896, 2631]
#
# Cluster 648:
# [2885, 2878, 2273, 1259]
#
# Cluster 968:
# [2883, 1631]
#
# Cluster 794:
# [2881, 549]
#
# Cluster 22:
# [2872, 2191, 1962, 1603, 1523, 1519]
#
# Cluster 883:
# [2867]
#
# Cluster 916:
# [2863]
#
# Cluster 770:
# [2862, 2206, 2204, 1687, 942, 801, 414, 373, 355, 31]
#
# Cluster 753:
# [2859]
#
# Cluster 536:
# [2855]
#
# Cluster 680:
# [2854]
#
# Cluster 785:
# [2853]
#
# Cluster 443:
# [2847, 2423]
#
# Cluster 449:
# [2845, 2102, 1400, 854, 492, 403]
#
# Cluster 15:
# [2844, 1849, 1009, 966, 934]
#
# Cluster 147:
# [2838, 2588, 2259]
#
# Cluster 715:
# [2837]
#
# Cluster 541:
# [2834, 2405]
#
# Cluster 898:
# [2833]
#
# Cluster 82:
# [2829, 1318]
#
# Cluster 135:
# [2828, 2527, 1934, 1435]
#
# Cluster 217:
# [2824, 2609, 2001]
#
# Cluster 836:
# [2820, 1193, 532, 525]
#
# Cluster 6:
# [2817, 2146, 1896, 1507, 183]
#
# Cluster 404:
# [2815, 2288]
#
# Cluster 375:
# [2806, 2773, 1559, 1453]
#
# Cluster 490:
# [2805]
#
# Cluster 465:
# [2802, 2483, 2170, 2061, 1942, 1624, 1593, 1399, 922, 653]
#
# Cluster 689:
# [2801, 2296, 1581, 1256, 320, 176]
#
# Cluster 640:
# [2800, 1826, 845, 205, 149]
#
# Cluster 616:
# [2791, 1667]
#
# Cluster 248:
# [2788, 2187, 1655, 998]
#
# Cluster 464:
# [2787, 1377, 739]
#
# Cluster 336:
# [2775, 1722, 1689]
#
# Cluster 953:
# [2768]
#
# Cluster 150:
# [2767, 1346, 1294]
#
# Cluster 621:
# [2763]
#
# Cluster 7:
# [2761, 507, 327]
#
# Cluster 183:
# [2758, 2656, 1388]
#
# Cluster 413:
# [2757, 2160]
#
# Cluster 800:
# [2753, 217, 104]
#
# Cluster 39:
# [2749, 2747, 2081, 2003, 1990, 1381, 953, 220, 146]
#
# Cluster 17:
# [2742, 2687, 2067, 1483, 587, 7]
#
# Cluster 625:
# [2731, 2600, 1783, 154]
#
# Cluster 142:
# [2726, 2581, 2031, 1698, 1488, 974, 920, 127]
#
# Cluster 819:
# [2725]
#
# Cluster 740:
# [2718, 2219, 581]
#
# Cluster 933:
# [2717]
#
# Cluster 658:
# [2705, 2430, 2382, 2100, 1209, 1126, 244]
#
# Cluster 254:
# [2697, 2148, 1338, 473]
#
# Cluster 140:
# [2695, 1342, 1291]
#
# Cluster 125:
# [2694, 2420, 2403, 2350, 1835]
#
# Cluster 497:
# [2692, 2690, 2648, 2076, 1735, 879, 253]
#
# Cluster 831:
# [2685]
#
# Cluster 495:
# [2684, 1773]
#
# Cluster 888:
# [2673]
#
# Cluster 936:
# [2668, 2444, 784, 768, 223]
#
# Cluster 385:
# [2665, 2312, 890]
#
# Cluster 244:
# [2661, 2043]
#
# Cluster 456:
# [2651, 2221, 855, 524, 67]
#
# Cluster 615:
# [2649]
#
# Cluster 57:
# [2647, 2195, 133]
#
# Cluster 802:
# [2643, 2331, 2315, 2237, 289]
#
# Cluster 346:
# [2641, 365, 268]
#
# Cluster 419:
# [2635]
#
# Cluster 986:
# [2634, 2317, 1171]
#
# Cluster 993:
# [2630]
#
# Cluster 817:
# [2623]
#
# Cluster 671:
# [2618]
#
# Cluster 568:
# [2615, 886]
#
# Cluster 92:
# [2614, 2358]
#
# Cluster 407:
# [2613, 2279, 1923, 983, 972, 152]
#
# Cluster 974:
# [2612, 1629, 980, 161]
#
# Cluster 102:
# [2606, 1067]
#
# Cluster 500:
# [2602]
#
# Cluster 835:
# [2596, 1768, 1182, 501]
#
# Cluster 280:
# [2595, 2539, 1850, 1129, 1031, 123, 73]
#
# Cluster 976:
# [2594]
#
# Cluster 639:
# [2593, 597]
#
# Cluster 382:
# [2589, 2505, 2188, 1257, 901, 723, 367]
#
# Cluster 306:
# [2586, 2091, 1707, 1339]
#
# Cluster 398:
# [2585, 2555, 2042]
#
# Cluster 180:
# [2572, 1957, 1753, 1741, 1473]
#
# Cluster 40:
# [2571, 792]
#
# Cluster 396:
# [2570, 2120, 1640, 614]
#
# Cluster 818:
# [2567, 2513, 1513, 779, 184]
#
# Cluster 16:
# [2565, 2519, 2005, 2004, 1686]
#
# Cluster 28:
# [2563, 1775, 450]
#
# Cluster 630:
# [2562, 1588, 1166, 763, 543, 542]
#
# Cluster 478:
# [2559, 2422, 2324]
#
# Cluster 813:
# [2557]
#
# Cluster 557:
# [2554]
#
# Cluster 692:
# [2553, 2425, 2352, 619, 518]
#
# Cluster 741:
# [2541, 2080, 2047, 730]
#
# Cluster 649:
# [2540, 2313]
#
# Cluster 928:
# [2535]
#
# Cluster 947:
# [2530, 2220, 178, 54]
#
# Cluster 155:
# [2528, 1825, 1652, 1501, 426]
#
# Cluster 784:
# [2525]
#
# Cluster 329:
# [2522, 2506, 2501, 1725, 1706, 762, 560]
#
# Cluster 379:
# [2521, 1330]
#
# Cluster 432:
# [2517, 2469, 2460, 519]
#
# Cluster 56:
# [2512, 1723, 1014, 954, 874, 550, 172, 88]
#
# Cluster 308:
# [2511, 1877, 1337, 1325, 353, 350, 344]
#
# Cluster 589:
# [2510, 476]
#
# Cluster 614:
# [2508]
#
# Cluster 173:
# [2503, 1068, 612, 232]
#
# Cluster 918:
# [2502]
#
# Cluster 670:
# [2500, 1295, 736]
#
# Cluster 223:
# [2496, 2320]
#
# Cluster 900:
# [2494, 191]
#
# Cluster 13:
# [2492, 2291, 2062]
#
# Cluster 386:
# [2487, 2198, 1810, 1457, 963, 882]
#
# Cluster 493:
# [2477, 2118, 2064, 816, 628]
#
# Cluster 860:
# [2474]
#
# Cluster 91:
# [2472, 1776, 1657, 1104]
#
# Cluster 687:
# [2471, 1912, 931]
#
# Cluster 452:
# [2458, 527, 466]
#
# Cluster 510:
# [2451, 2262, 1576, 1303, 1242, 741, 91]
#
# Cluster 133:
# [2448, 1964, 1845, 1731, 1309, 1105, 531]
#
# Cluster 436:
# [2447, 1999, 1749, 1648, 1554, 489]
#
# Cluster 877:
# [2445]
#
# Cluster 43:
# [2439, 1780, 1138, 856]
#
# Cluster 526:
# [2436, 1977, 1750, 1396, 1053, 213]
#
# Cluster 798:
# [2435, 2427, 2251, 2021, 2018, 1688, 1124]
#
# Cluster 453:
# [2421, 435]
#
# Cluster 97:
# [2417, 2389, 727]
#
# Cluster 759:
# [2407, 1759]
#
# Cluster 713:
# [2401]
#
# Cluster 708:
# [2400]
#
# Cluster 663:
# [2398, 1161]
#
# Cluster 152:
# [2395, 1985, 1660, 881, 374]
#
# Cluster 186:
# [2393, 981, 898]
#
# Cluster 187:
# [2387, 1888, 1048, 915]
#
# Cluster 837:
# [2383]
#
# Cluster 154:
# [2381, 2377, 1288, 509]
#
# Cluster 765:
# [2374]
#
# Cluster 758:
# [2368]
#
# Cluster 89:
# [2365, 2057, 2029, 2025, 1092, 1020]
#
# Cluster 582:
# [2360]
#
# Cluster 384:
# [2357, 576, 99]
#
# Cluster 412:
# [2354, 418]
#
# Cluster 973:
# [2346]
#
# Cluster 287:
# [2344, 2341]
#
# Cluster 48:
# [2339, 2289, 2126, 1881, 1199]
#
# Cluster 527:
# [2334]
#
# Cluster 686:
# [2329]
#
# Cluster 908:
# [2326]
#
# Cluster 537:
# [2322, 1328]
#
# Cluster 18:
# [2318, 848, 281, 255]
#
# Cluster 267:
# [2311, 1596]
#
# Cluster 572:
# [2308, 2085]
#
# Cluster 88:
# [2307, 1616, 1178, 361]
#
# Cluster 884:
# [2305]
#
# Cluster 124:
# [2298, 2192]
#
# Cluster 441:
# [2295]
#
# Cluster 932:
# [2293]
#
# Cluster 314:
# [2292, 2269, 1837, 1345, 295]
#
# Cluster 265:
# [2287, 1904, 1726]
#
# Cluster 240:
# [2283, 2065, 2055, 1659, 1248]
#
# Cluster 277:
# [2281, 867, 637]
#
# Cluster 825:
# [2256]
#
# Cluster 53:
# [2252, 2189, 1508, 579]
#
# Cluster 540:
# [2245, 2193, 2175, 1333, 865]
#
# Cluster 216:
# [2243, 100]
#
# Cluster 804:
# [2240]
#
# Cluster 116:
# [2231, 2174, 2113]
#
# Cluster 330:
# [2227, 1530, 744]
#
# Cluster 463:
# [2226]
#
# Cluster 560:
# [2225]
#
# Cluster 822:
# [2224, 1023, 696]
#
# Cluster 195:
# [2217, 2026, 964]
#
# Cluster 889:
# [2215]
#
# Cluster 408:
# [2205, 302]
#
# Cluster 581:
# [2197, 1909]
#
# Cluster 566:
# [2190, 539]
#
# Cluster 896:
# [2177]
#
# Cluster 863:
# [2169, 1445, 967]
#
# Cluster 430:
# [2168, 1802, 1546, 1460, 520]
#
# Cluster 696:
# [2152, 911, 381, 271]
#
# Cluster 9:
# [2149, 1858, 1605, 906]
#
# Cluster 504:
# [2141, 2006, 449, 218]
#
# Cluster 423:
# [2128, 89]
#
# Cluster 950:
# [2127, 2008, 1774, 231]
#
# Cluster 567:
# [2122, 1313]
#
# Cluster 685:
# [2117, 1224]
#
# Cluster 225:
# [2106, 314]
#
# Cluster 924:
# [2105]
#
# Cluster 664:
# [2093, 2063, 2015]
#
# Cluster 821:
# [2092, 2066]
#
# Cluster 514:
# [2089, 1695, 254, 233, 97]
#
# Cluster 26:
# [2086, 1976, 1615, 1540, 999, 989, 703, 109]
#
# Cluster 263:
# [2084]
#
# Cluster 619:
# [2072, 888, 334]
#
# Cluster 870:
# [2060, 2022, 1778, 1736, 1678, 1402, 1044]
#
# Cluster 678:
# [2059, 1690, 772]
#
# Cluster 114:
# [2049, 1756, 1010, 118]
#
# Cluster 257:
# [2035, 508]
#
# Cluster 184:
# [2030, 1227]
#
# Cluster 893:
# [2027, 1811, 130]
#
# Cluster 368:
# [2024, 629]
#
# Cluster 444:
# [2020, 1228, 593]
#
# Cluster 353:
# [2019, 1932, 1216]
#
# Cluster 350:
# [2017, 262]
#
# Cluster 754:
# [2014, 1838]
#
# Cluster 593:
# [2009]
#
# Cluster 820:
# [2000]
#
# Cluster 393:
# [1991, 1565]
#
# Cluster 922:
# [1987, 458]
#
# Cluster 246:
# [1983, 1426, 988, 909]
#
# Cluster 799:
# [1974, 1233, 1084]
#
# Cluster 673:
# [1961, 1263, 663, 340]
#
# Cluster 338:
# [1959, 1938, 1518]
#
# Cluster 728:
# [1955]
#
# Cluster 370:
# [1952, 1630, 1164, 144]
#
# Cluster 767:
# [1946, 180]
#
# Cluster 321:
# [1945, 1879, 1871, 1382, 481]
#
# Cluster 406:
# [1944, 1413, 1088]
#
# Cluster 341:
# [1933, 1504, 1036, 1012, 899]
#
# Cluster 328:
# [1920, 1289, 611, 407]
#
# Cluster 451:
# [1915, 1070, 634]
#
# Cluster 198:
# [1889, 1867]
#
# Cluster 498:
# [1886, 406]
#
# Cluster 725:
# [1883]
#
# Cluster 383:
# [1872, 697, 424]
#
# Cluster 674:
# [1864, 787]
#
# Cluster 268:
# [1847, 1184]
#
# Cluster 369:
# [1846, 1089]
#
# Cluster 418:
# [1844, 65]
#
# Cluster 211:
# [1833, 1135, 378, 357]
#
# Cluster 634:
# [1830]
#
# Cluster 391:
# [1829]
#
# Cluster 403:
# [1824, 1472, 952]
#
# Cluster 866:
# [1814]
#
# Cluster 310:
# [1813, 604, 521]
#
# Cluster 601:
# [1804, 767, 486]
#
# Cluster 766:
# [1798, 1385]
#
# Cluster 774:
# [1795, 1069]
#
# Cluster 629:
# [1791, 839]
#
# Cluster 66:
# [1790, 419]
#
# Cluster 380:
# [1782, 1245, 624]
#
# Cluster 177:
# [1779, 1219]
#
# Cluster 872:
# [1777, 1454, 533]
#
# Cluster 790:
# [1758]
#
# Cluster 607:
# [1733]
#
# Cluster 612:
# [1713, 17]
#
# Cluster 980:
# [1697]
#
# Cluster 238:
# [1693, 728]
#
# Cluster 880:
# [1669]
#
# Cluster 148:
# [1653, 1082]
#
# Cluster 326:
# [1651, 277]
#
# Cluster 272:
# [1646, 1643]
#
# Cluster 772:
# [1644]
#
# Cluster 746:
# [1639]
#
# Cluster 553:
# [1635]
#
# Cluster 502:
# [1634]
#
# Cluster 773:
# [1612, 1510, 674, 448, 228]
#
# Cluster 743:
# [1608, 698]
#
# Cluster 931:
# [1600, 1358]
#
# Cluster 562:
# [1597, 582]
#
# Cluster 892:
# [1584, 1583]
#
# Cluster 168:
# [1578, 631]
#
# Cluster 584:
# [1572, 1177, 511]
#
# Cluster 718:
# [1571, 85]
#
# Cluster 110:
# [1570, 1515, 774, 559, 319]
#
# Cluster 977:
# [1561, 1549, 726, 677]
#
# Cluster 481:
# [1560, 962, 959, 76]
#
# Cluster 538:
# [1548, 826, 719]
#
# Cluster 842:
# [1545]
#
# Cluster 797:
# [1537]
#
# Cluster 234:
# [1532, 1329, 633]
#
# Cluster 175:
# [1531, 478]
#
# Cluster 871:
# [1522, 544]
#
# Cluster 598:
# [1511]
#
# Cluster 475:
# [1506, 93]
#
# Cluster 894:
# [1498]
#
# Cluster 44:
# [1486, 651, 306, 182]
#
# Cluster 763:
# [1477]
#
# Cluster 337:
# [1470, 592]
#
# Cluster 401:
# [1469, 917]
#
# Cluster 472:
# [1461, 1306]
#
# Cluster 530:
# [1455, 1450]
#
# Cluster 429:
# [1449]
#
# Cluster 992:
# [1444]
#
# Cluster 232:
# [1437, 1434, 1427, 1410, 929]
#
# Cluster 551:
# [1419, 919, 266]
#
# Cluster 638:
# [1412]
#
# Cluster 409:
# [1401, 1197]
#
# Cluster 693:
# [1398, 1163, 1078, 913, 724, 30]
#
# Cluster 90:
# [1383, 1347, 760, 647]
#
# Cluster 596:
# [1375, 1142]
#
# Cluster 376:
# [1366, 12]
#
# Cluster 119:
# [1363, 1350]
#
# Cluster 597:
# [1341, 274]
#
# Cluster 480:
# [1335, 260]
#
# Cluster 677:
# [1324]
#
# Cluster 428:
# [1320, 1262, 1127]
#
# Cluster 565:
# [1316]
#
# Cluster 284:
# [1314, 1181]
#
# Cluster 684:
# [1311, 328]
#
# Cluster 488:
# [1307, 578, 348]
#
# Cluster 853:
# [1305]
#
# Cluster 32:
# [1296, 1195]
#
# Cluster 878:
# [1287]
#
# Cluster 461:
# [1273, 914]
#
# Cluster 710:
# [1267]
#
# Cluster 349:
# [1264, 1003, 207]
#
# Cluster 958:
# [1260]
#
# Cluster 293:
# [1255, 793]
#
# Cluster 59:
# [1252, 504]
#
# Cluster 609:
# [1251]
#
# Cluster 858:
# [1250, 607]
#
# Cluster 729:
# [1246]
#
# Cluster 920:
# [1241]
#
# Cluster 697:
# [1238]
#
# Cluster 994:
# [1225]
#
# Cluster 543:
# [1223]
#
# Cluster 913:
# [1222]
#
# Cluster 830:
# [1208]
#
# Cluster 531:
# [1205]
#
# Cluster 786:
# [1198]
#
# Cluster 438:
# [1196]
#
# Cluster 656:
# [1191]
#
# Cluster 834:
# [1190]
#
# Cluster 745:
# [1188]
#
# Cluster 665:
# [1186]
#
# Cluster 703:
# [1168]
#
# Cluster 365:
# [1167, 732]
#
# Cluster 486:
# [1162, 497]
#
# Cluster 577:
# [1160, 1143]
#
# Cluster 990:
# [1147, 1141, 649]
#
# Cluster 602:
# [1130]
#
# Cluster 440:
# [1128, 717]
#
# Cluster 736:
# [1122]
#
# Cluster 954:
# [1121]
#
# Cluster 156:
# [1108, 275]
#
# Cluster 921:
# [1098]
#
# Cluster 632:
# [1090, 973]
#
# Cluster 856:
# [1072]
#
# Cluster 575:
# [1063]
#
# Cluster 230:
# [1047, 459]
#
# Cluster 197:
# [1041, 471, 256]
#
# Cluster 676:
# [1025]
#
# Cluster 832:
# [1022, 722]
#
# Cluster 29:
# [1015, 586]
#
# Cluster 901:
# [1006, 715]
#
# Cluster 41:
# [978, 642, 491, 215]
#
# Cluster 997:
# [977]
#
# Cluster 592:
# [971, 71]
#
# Cluster 885:
# [944]
#
# Cluster 521:
# [930, 742]
#
# Cluster 963:
# [926]
#
# Cluster 460:
# [887, 782]
#
# Cluster 433:
# [876, 457]
#
# Cluster 987:
# [857]
#
# Cluster 732:
# [850]
#
# Cluster 930:
# [806, 494]
#
# Cluster 571:
# [789, 197]
#
# Cluster 695:
# [756]
#
# Cluster 722:
# [743]
#
# Cluster 595:
# [720]
#
# Cluster 20:
# [713, 305]
#
# Cluster 79:
# [712, 680, 257]
#
# Cluster 711:
# [708]
#
# Cluster 271:
# [694, 652]
#
# Cluster 662:
# [671]
#
# Cluster 854:
# [660, 442]
#
# Cluster 771:
# [659]
#
# Cluster 544:
# [641]
#
# Cluster 966:
# [639]
#
# Cluster 659:
# [630, 595]
#
# Cluster 782:
# [620, 583]
#
# Cluster 793:
# [608]
#
# Cluster 939:
# [600]
#
# Cluster 518:
# [598]
#
# Cluster 955:
# [596]
#
# Cluster 735:
# [573]
#
# Cluster 951:
# [569]
#
# Cluster 886:
# [546]
#
# Cluster 749:
# [503]
#
# Cluster 361:
# [502, 304]
#
# Cluster 998:
# [500]
#
# Cluster 873:
# [469]
#
# Cluster 160:
# [447, 402]
#
# Cluster 52:
# [445, 297, 283]
#
# Cluster 897:
# [444]
#
# Cluster 33:
# [443, 364]
#
# Cluster 466:
# [438]
#
# Cluster 586:
# [431]
#
# Cluster 477:
# [429, 359]
#
# Cluster 372:
# [422]
#
# Cluster 899:
# [421]
#
# Cluster 949:
# [420]
#
# Cluster 517:
# [413]
#
# Cluster 506:
# [405]
#
# Cluster 552:
# [401]
#
# Cluster 971:
# [399]
#
# Cluster 861:
# [394]
#
# Cluster 809:
# [393]
#
# Cluster 979:
# [391]
#
# Cluster 624:
# [390]
#
# Cluster 392:
# [389]
#
# Cluster 935:
# [388]
#
# Cluster 559:
# [385]
#
# Cluster 929:
# [384]
#
# Cluster 523:
# [377]
#
# Cluster 651:
# [371]
#
# Cluster 611:
# [358]
#
# Cluster 737:
# [356]
#
# Cluster 909:
# [352]
#
# Cluster 679:
# [349]
#
# Cluster 823:
# [347]
#
# Cluster 459:
# [345]
#
# Cluster 622:
# [342]
#
# Cluster 599:
# [341]
#
# Cluster 989:
# [338]
#
# Cluster 838:
# [337]
#
# Cluster 904:
# [335]
#
# Cluster 717:
# [326]
#
# Cluster 882:
# [325]
#
# Cluster 515:
# [322, 312]
#
# Cluster 512:
# [313]
#
# Cluster 862:
# [311]
#
# Cluster 484:
# [310]
#
# Cluster 660:
# [293]
#
# Cluster 654:
# [292]
#
# Cluster 775:
# [290]
#
# Cluster 561:
# [288]
#
# Cluster 829:
# [287]
#
# Cluster 299:
# [285]
#
# Cluster 60:
# [278, 264]
#
# Cluster 694:
# [269]
#
# Cluster 705:
# [265]
#
# Cluster 867:
# [263]
#
# Cluster 339:
# [261]
#
# Cluster 716:
# [246]
#
# Cluster 642:
# [237]
#
# Cluster 923:
# [198]
#
# Cluster 626:
# [171]
#
# Cluster 983:
# [170]
#
# Cluster 690:
# [58]

# %%
import os

poems_cluster_dir = f'../data/processed/userade/poems_cluster/{n_clusters}'
os.makedirs(poems_cluster_dir, exist_ok=True)

# %%
for group_name, group in df.groupby('cluster'):
    group = group.drop(columns=['cluster'])
    group.to_csv(f'{poems_cluster_dir}/{group_name}.csv', index=False)
