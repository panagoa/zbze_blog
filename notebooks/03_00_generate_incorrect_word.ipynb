# %%
import nltk

from src.logic.text_cleaner import clean_text

with open('../data/processed/word_freqs/freq_1000000_oshhamaho.txt') as f:
    text = f.read()

clean_text = clean_text(text)

book_words = nltk.word_tokenize(text)

# %%
fdist = nltk.FreqDist(book_words)

# %%
filtered_words = [word for word, freq in fdist.items() if freq < 2]

# %%
import random


def generate_typo(word):
    typo_type = random.choice(['swap', 'delete', 'insert'])
    if len(word) < 2:
        typo_type = 'insert'

    if typo_type == 'swap':
        idx = random.randint(0, len(word) - 2)
        word = word[:idx] + word[idx + 1] + word[idx] + word[idx + 2:]

    elif typo_type == 'delete':
        idx = random.randint(0, len(word) - 1)
        word = word[:idx] + word[idx + 1:]

    elif typo_type == 'insert':
        idx = random.randint(0, len(word))
        alphabet = (
            'АаБбВвГгДдЕеЁёЖжЗзИиЙйКкЛлМмНнОоПпРрСсТтУуФфХхЦцЧчШшЩщЪъЫыЬьЭэЮюЯяIi1'
            '-.,:; -!?–…«»1234567890)(№*×><'
            'IIIьььъъъi111'
        )
        random_letter = random.choice(alphabet)
        word = word[:idx] + random_letter + word[idx:]

    return word


def generate_similar_char_error(word):
    similar_letters = {
        'п': 'II',
        'пI': 'тШ',
        'гы': 'гЫ',
        'жы': 'жь',
        'шы': 'шь',
        'П': 'ТТ',
        'Ш': 'III',
        'ш': 'III',
        'ПI': 'ПIГ',
        'жэ': 'жо',
        'пэ': 'пы',
        'жь': 'жъ',
        'ий': 'нй',
        'пс': 'лс',
        'эм': 'эи',
        'щ': 'шщ',
        'къ': 'кь',
        'Къ': 'Жъ',
        'пл': 'нл',
        'им': 'нм',
        'ти': 'тн',
        'гъщ': 'гъц',
        'хуи': 'хун',
        'щх': 'шх',
    }
    for key, value in similar_letters.items():
        if key in word:
            word = word.replace(key, value)
            break
    return word


def generate_grammatical_suffix_error(word):
    if word.endswith('къым'):
        return word[:-4] + 'кым'
    elif word.endswith('мкIэ'):
        return word[:-4] + 'мкэ'
    elif word.endswith('ым'):
        return word[:-2] + 'ып'
    return word


def generate_grammatical_prefix_error(word):
    if word.startswith('зэры'):
        return 'зари' + word[4:]
    elif word.startswith('къых'):
        return 'кыху' + word[4:]
    return word


def gen_incorr_word(word):
    incorrect_word = word

    for func in [
        generate_grammatical_prefix_error, 
        generate_grammatical_suffix_error, 
        generate_similar_char_error,
        generate_typo
    ]:
        incorrect_word = func(incorrect_word)
        if incorrect_word != word:
            return incorrect_word

    return incorrect_word


synthetic_spelling_errors = set()
for word in filtered_words:
    incorrect_word = gen_incorr_word(word)
    if incorrect_word != word:
        synthetic_spelling_errors.add(incorrect_word)

# %%
synthetic_spelling_errors
# Out:
# {'хъуIIIэкIэ',
#  'зэIIлъыжурэ',
#  'ХуоIIсэури',
#  'НетэI',
#  'зэшэлIэжынып',
#  'зариIукIыжхэр',
#  'фыдэзгъэхьэнукым',
#  'къызэрыдрашщIей',
#  'семыIIсыхыжу',
#  'Тетхрэ',
#  'ЖъызэрымыкIуар',
#  'Къалмыкьыбзэ',
#  'автомаIIIинэхэм',
#  'тахътэбаынр',
#  'зарихуекIуэр',
#  'фыкъэдаIуэркым',
#  'шщхьэусыгъуэ-',
#  'зыкьызэридзэкIыжу',
#  'IуэхущIафэирэ',
#  'къышщыкIэлъыдэжи',
#  'зытриуху',
#  'къышщIагъэшщашщ',
#  'риилъэгъуат',
#  'шщIэгъэкъуа',
#  'укьытемыухь',
#  'уэриа',
#  'къышщIэувэ',
#  'гъуэIIлъ-гъуэжьыгъэм',
#  'рудр',
#  'Хъуашщ',
#  'Жъосыжри',
#  'къышщIыхьати',
#  'зыгъэкIэрхаъуэу',
#  'ущыIIсэуныр',
#  'хэкIуэтаэ',
#  'кьыддеIэу',
#  'къэдгъуэтыншщ',
#  'зытемыхуъэ',
#  'УемыIIлъыт',
#  'кьазри',
#  'къигъэщIакым',
#  'сфыочауэ',
#  'сыкьикIыжмэ',
#  'лъагаIIIэри',
#  'Усыгъэхэирэ',
#  'гъэкIуауэ',
#  'кыхуигъэщат',
#  'къышщрикIуташщ',
#  'дыэритрэ…',
#  'IIхуагъэхъей',
#  'рзиIэтыкIауэ',
#  'къышщихьэжам',
#  'къэзгъэшщIэнур',
#  'кьытхэкIауэ',
#  'шщабэти',
#  'къызэгъэпэщынымкэ',
#  'уегуакIуэи',
#  'фшхыжьнурэ',
#  'зэрагъэтыншьнрэ',
#  'зарихъуэнар',
#  'чубу;к',
#  'Комеат',
#  'Жыгбэгцу',
#  'Дэкамэ',
#  'зэхуеIIIэсыжри',
#  'щIэуIIщIэшхуи',
#  'ДылIэнушщ',
#  'къызэшщIэскъуэурэ',
#  'кыхуузэщIэнауэ',
#  'Еджашщ',
#  'зарисщIынухэм',
#  'зэIытхи',
#  'фызэIIрысыкIыу',
#  'драгъуейрт',
#  'схуIIымыщэу',
#  'Быбэшщ',
#  'Джамилей',
#  'зэиргъэзахуэрт',
#  'гъэкъэбзэнхуейуэаркъудейшщ',
#  'мыгъужьн',
#  'къытшщрехьэ',
#  'здэкIуэжып',
#  'зыхуэныкъуэ-зыщIэуIIщIэхэр',
#  'ГъашщIи',
#  'хьэжьгъэу',
#  'къашщыхуихуар',
#  'толъкьуныр',
#  'къысхуэфшщIыну',
#  'къишэIIэнуми',
#  'ушщIыдэкIын',
#  'къытшщыхъужми',
#  'къыIIкIэлъыIIлъын',
#  'дызэщхькым',
#  'кьытрадзат',
#  'комерсант',
#  'ьХуд',
#  'сыз№эрыгъар',
#  'сыдэсыжыфыркым',
#  'сожохри',
#  'шщызэхуалъэфэсыжа',
#  'яхэтакьым…',
#  'кьратарэ',
#  'уилIЬми',
#  'уэрэдишщыр',
#  'Милицэи',
#  'шщIэугъурсызыр',
#  'ДыкъышщалъагъукIэ',
#  'зарижаIэнуми',
#  'яхэIIлъэжащ',
#  'угбъэдыхьат',
#  'къызеIIIэкI',
#  'сыкьримыдзэу',
#  'зэIуыруа',
#  'зыщыдгуэшьнущ',
#  'хъунхр',
#  'фэикIи',
#  'МыIIщэдджыжьырзэрыщытуIIшагъуэт',
#  'триъэу-',
#  'аДуткIэ',
#  'Iэдэжьмрэ',
#  'сыхуэбгъэсашщ',
#  'шщысIуэтэншщ',
#  'АIIIрэф',
#  'гулыътэри',
#  'трагъаури',
#  'ксаог-кIэ',
#  'хьэбзыIIэр',
#  'пезгъэупщIынкым',
#  'мэхъэж',
#  'Нэиыцэр',
#  'къахуигъэкIуашщ',
#  'егбъэдэIуэныр',
#  'тМетх',
#  'кьебгъэну',
#  'тегъуалъхьэхэрт ',
#  'кIэззырэ',
#  'укъишхыдыкIыIIащ',
#  'къышщIызэлъэIуауэ',
#  'узэрыщыджогум',
#  'триIуэнтIэжашщ',
#  'зытетшщIыхьыну',
#  'Джденерэ',
#  'эзгуиуду',
#  'зэфIэтхъм',
#  'увагъашщIэ',
#  'шщIихъумарэ',
#  'бэмIIIэгъуэт',
#  'жъэдилъхьэу',
#  'яжъыщIа',
#  'бригадэхэирэ',
#  'хилъагъкуIыр',
#  'къытрикъуташщ',
#  'зызгъэIIскIыфу',
#  'хилъэфалуэ',
#  'траъазэурэ',
#  'ягъэхмэ',
#  'щогъуIIщэж',
#  'кIэлъыIIлъакIуэхэр',
#  'ефшщIэркъэ',
#  'зарипэжыжьэрщ',
#  'къызэригъэшщIа',
#  'кыхуихынур',
#  'хабзэи…',
#  'къызэтегъэнэнып',
#  'Услэгъуауэ',
#  'ГушщIагъшщIэлъ',
#  'къышщытеувэжа',
#  'СаIIэджэжам',
#  'дышщыIэшщ',
#  'биубыдэр…',
#  'сыIIыщIат',
#  'IIхуохъуж',
#  'щIиIIлъыкIа',
#  'ибзыщIынутэкым',
#  'къэшщэбэжауэ',
#  'IIIЕЙ',
#  'къокIахэи',
#  'IуIIлъэжынт',
#  'тщIэххэртэкым',
#  'зегъэужъакIуэ',
#  'нысфIыдэIээбну',
#  'къахотэджькI',
#  'ЩIызышщигъэгугъар',
#  'лъэIIкъ-щхьэхуитщIыжакIуэ',
#  'ТТщыгъэунэхъу',
#  'устхьэлэншщ',
#  'дэлъэдаIIIэм',
#  'схэуэу',
#  'фыкIуэми',
#  'къигъэтIылъашщ',
#  'хуезыгъаджоу',
#  'щыхэмытIаIIхъэ',
#  'хреымху',
#  'Брст',
#  'къолъэIIэуэжынкIэ',
#  'къэетэжашщ',
#  'усщыгъуIIщэжынущ',
#  'зумыIIлъыхь',
#  'IIIащэхэри',
#  'къызэрыхэтхынып',
#  'тIасхъэшщ',
#  'СышщымыIэжушщ',
#  'дахэзыгъаIIлъэ',
#  'СызэгуIIсысын',
#  'бжьыфIэIIIхуэр',
#  'дахэртн',
#  'аркъэи',
#  'ХэкIынушщ',
#  'гуэгуэнхрэ',
#  'къэзыубыдып',
#  'зыхищIэжьрт',
#  'Урысбнйхэ',
#  'сИстамбыл-Аюб',
#  'сыщыIэжатэи',
#  'къхухьитI',
#  'зэхэутхъуэи',
#  'щигъэуфафэи',
#  'д0ызэсэри',
#  'къыIIхиха',
#  'умыIIсэуныр',
#  'зарихутридзауэ',
#  'узыпхьу',
#  'кьысIухужурэ',
#  'Зэкнй',
#  'гъуэгужърэ',
#  'хьэмрнйкIэ',
#  'IIыкIуэтри',
#  'Жорр',
#  'рагъэзыхауэ',
#  'зэбгъуырту',
#  'ГуIIцIанэм',
#  'ТТавароттищ',
#  'IтыкIуэ',
#  'хигъэгуIIсысыхьыжауэ',
#  'сыдэкIуэжаIып',
#  'дакъыхэзыгъэшщхьэхукI',
#  'дэIIу',
#  'уIIсэуфын',
#  'ХухеIII',
#  'зэтелъыхэх',
#  'сызэхыуемыхыжу',
#  'IIащIэгъуэкIэ',
#  'техамэ',
#  'иракIэ-ри',
#  'гъаж1и',
#  'къышщIэхъуэн',
#  'зыбгъэншщI',
#  'КIэлъкыIуэри',
#  'кьилъыхъуэ',
#  'къэкъуалъэи',
#  'шщагъэхъуми',
#  'зогъэшщакIуэ',
#  'хаухьырт',
#  'йсыхыр',
#  'яхудоук',
#  'егэнэрылъагъу',
#  'тригуэIIIащ',
#  'зыцIыхухэрт.',
#  'Зэрышщытам',
#  'къыщетIIIэкIыр',
#  'зарищыщтэр',
#  'хуокIуэ',
#  'Людмбилы',
#  'хэIIлъэгъуэр',
#  'щIэдэIуфхэиэ',
#  'яIIIхаи',
#  'ядоIIIэс',
#  'шьгъуэгуи',
#  'кыхууэслъэфар',
#  'трегъэкIЕыж',
#  'вгъуэтынукым',
#  'Усхунмыту',
#  'зэхуаIаутэ',
#  'мавзолейхэирэ',
#  'хэшыIIсыхьыжыну',
#  'тегуIIIхуа',
#  'шщхьэемыгугъушщ',
#  'КъигъэIIцIащ',
#  'зэхэуэшщIэ',
#  'яхуэиыхьу',
#  'къыщытхуеIIсыхар',
#  'кьэзыгъэхуабэр',
#  'шщытыкIами',
#  'вагоныжъхэм',
#  'иукьуэдияуэ',
#  'ызгъэлIэнт',
#  'сышщыгъуашщэу',
#  'кIэрысIулIашщ',
#  'къэтIысыжыркым',
#  'щIалэгъуэ-хъыжъэгъуэр',
#  'зарилэжьэн',
#  'ЩрагъэжъэжкIэ',
#  'Зышщыбгъэлъэгъуэн',
#  'бгъукэIрэ',
#  'къызэрашщэхун',
#  'сыкъоджо',
#  'уэрамымкэ',
#  'зэкIэщIихужьнщи',
#  'худыбоычхыIуэ',
#  'къыIIхуашийурэ',
#  'нтиIысхьэ',
#  'кьисхат',
#  'къышщыдэзгъэкIа',
#  'сышщхьэдэхыжашщ',
#  'здраIIIэжьэжу',
#  'Согъэкьабзэ',
#  'сIIIэчынт',
#  'Ехуднй',
#  'Ивановнэриi',
#  'зарищIэгупсысым',
#  'аршщхьэкIэ',
#  'мыгъуэшщ…',
#  'зарифагъуэмрэ',
#  'кьахыболъагъукI',
#  'депIэщIэкIынкым',
#  'Гъаузэри',
#  'итар',
#  'зыхэлэжъыхьыжа',
#  'ТТэмыхъуну',
#  'ТТыф-сыф',
#  'яхузэридзэкIашщ',
#  'ныбжъынт…',
#  'нмыух',
#  'къиIIча',
#  'ЩыIIоткIу',
#  'здытетып',
#  'игъэбелджьлыуэ',
#  'щыгуIIкIэу',
#  'укъимыужэгъужыIIамэ',
#  'ЕЗытхари',
#  'зэтхыжашщ',
#  'шщIисыкIыу',
#  'иритыфашщ',
#  'Ихсьант',
#  'шщысшщхьэшщыум',
#  'дэиыхъей',
#  'мыабрагъуэии',
#  'тетшщIыхьыншщ',
#  'зыщагъэбыдащПсыфIыIIсхэлъадэIIсыежэххэркъыщежьэжьанэхэм',
#  'къушщIатыжар',
#  'длаъэу',
#  'къаIIIий',
#  'ягъэIIIэсыфырт',
#  'доргуфIэ',
#  'бэяи',
#  'IIсэуфу',
#  'арстворрэ',
#  'щыIIэмыIIлъэ',
#  'шщыIэншщ…',
#  'едкIуу',
#  'ЦIыIу',
#  'яхиубыдашщ',
#  'зэхуащIыжьнущ',
#  'IукIуэташщ',
#  'ЖъБР',
#  'ХъуакIуитI',
#  'якъуэиылIыкI',
#  'ноIIлъэ',
#  'ыгъэкIуасэу',
#  'хъыджэбзыIIIхуэр',
#  'IкуIыжри',
#  'сыхуейтэкым',
#  'уфIыцIаэ',
#  'тшщIынт',
#  'нэшщхъыфIэрэ',
#  'сыкъацIыхуркым',
#  'тхутричырт(',
#  'кьысхуэбгъэлъэгъуа',
#  'къыIIкIэрымыхуамэ',
#  'Диижашщ',
#  'едгъэшщIашщ',
#  'схуэфашщэуи',
#  'сышщышщакIуэрт',
#  'кьэтлъагъуми',
#  'унмыхьауэ',
#  'Хэбцу',
#  'ираудыхашщи',
#  'ауэкым',
#  'къыIIкърыуа',
#  'щIэгъэIIщкIуа',
#  'гуащIэиэ',
#  'Езыхэрашщ',
#  'уэрэдыжъ',
#  'къыщыщIидзэжьнур',
#  'лъыстуаэ',
#  '18к37',
#  'ныбжъыр-щэ',
#  'ухигъэдэнушщ',
#  'ТТсэукIэ-Дахэ',
#  'КIэшщI',
#  'хузэфIэкIыжакым',
#  'гъыбзэрау',
#  'зымыдхаэр',
#  'ЦIыхфI',
#  'ЩIэи',
#  'илъыжашщ',
#  'сиIаЪмэ',
#  'ансамблып',
#  'къыщыдгъэсэбэIIа',
#  'ушщецIэнтхъуэхыжкIэ',
#  'Iэна.тIитIри',
#  'КъаукIакым',
#  'къигъэшщIагъэншщ',
#  'зарищIащIам',
#  'еIIIэщIэкIмэ',
#  'Еджонуи',
#  'IIщIэншэт',
#  'IIолъку',
#  'зэпыщIэныгъэракым',
#  'къыщызимытып',
#  'сыкъехуэхынып',
#  'кIэрышщIэну',
#  'шщатIар',
#  'къэбгуIIсысащ',
#  'кIэрыныкьа',
#  'сыкъилъагъукым',
#  'узэрыщытыIIхъэу',
#  'снмыгъэлъагъун',
#  'сыШмыдэн',
#  'зарихуэмыщIам',
#  'гурышщхъуэри',
#  'хуэбутIыIIщын',
#  'КъыщыIIхуэзэн',
#  'уче!тымрэ',
#  'сыкъыдэуджакым',
#  'IуэхухэикIэ…',
#  'ишщам',
#  'заризэхуаIуатэ',
#  'джогуныр',
#  'кыхууэмеиж',
#  'кафедрэщIэи',
#  'къыIIидзыжырт',
#  'кьэзыэтыж',
#  'Iэибатэхэирэ',
#  'ДызыхуэзЮа',
#  'ЗратарIи',
#  'языхэз–и',
#  'хэзымыгъэшщI',
#  'дыкъыщIеIIщIэкIыр',
#  'жондауру',
#  'IIэжынущ',
#  'зарищIа-',
#  'цIыкIукIэтэкым',
#  'йэохьри',
#  'нэбгъэкIуаэ',
#  'къызжефIэиэ',
#  'дыдэхэи',
#  'фIБэкIат',
#  'зреIОуэнтIыхь',
#  'къаухашщ',
#  'зэIешщIэж',
#  'игъэтIеуйэ',
#  'зэIIкърихыфауэ',
#  'обновляютс',
#  'хэIIлъэгъуэщи',
#  'садэиыхъункIэ',
#  'сыбгъэдэсынушщи',
#  'шщIагъурти',
#  'часовоишщIэ',
#  'Тимуршщ',
#  'мылъытэкьэ',
#  'Бармалейв',
#  'IIкъыфIэм',
#  'IэиалыщIэу',
#  'щригъажъэм',
#  'ишщтар',
#  'махунбгъурэ',
#  'зэбгрымылэжъыкIыу',
#  'ВетерИинару',
#  'здиIIIагъэнущ',
#  'Дызэхуээ',
#  'къыIIхуагъэхьащ',
#  'сызэрыхуэзэIIIри',
#  'иихуэкIыу',
#  'Жансурэтшщ',
#  'грономымрэ',
#  'Сыбырыжьып',
#  'кьедгъэцIыхуну',
#  'кьрадзэри',
#  'шщIытригъэкIуадэр',
#  'лъагишщ',
#  'кьимыхуэххэнкIи',
#  'укьэкIуэхха',
#  'сос',
#  'сыпэрыуэфакым',
#  'уфIэшьнагъуэщ',
#  'кьызэрыстехьэлъар',
#  'зарихигъэхъуэным',
#  'Зыгъэгыузавэри',
#  'къызэрыIIхри',
#  'зыкъызэрыхуигъэиакъыхъури',
#  'Къызжъэхигъэуакъыми',
#  'IIэщIидзыну',
#  'ИригуIIIхуэут',
#  'зыунэтIЬынур',
#  'фоачуэр',
#  'дзынэса',
#  'Дыщэ-дыжъыну',
#  'Нм',
#  'IIтрихынурэ',
#  'ЩытхъуриакъыIIщытхъурщзэлъытар',
#  'долэт-джорий',
#  'КлубыIIIхуэм',
#  'ишщIыфт',
#  'ЯIэшщIэкIа',
#  'ехашщ',
#  'шьтесу',
#  'маГуауэшщхьэуэ',
#  'IIовеса',
#  'кIэрыгъушщхьэжат',
#  'кьызэракьутар',
#  'IIасэрейщ',
#  'Дыхуейдыхуэиейми',
#  'сызэIIрихыну',
#  'уфэ-упцIэмкэ',
#  'дыкIунэнуи',
#  'диалектр?и',
#  'сыкьрахьэкIырт',
#  'тиIIологие',
#  'къытхуаIIIэж',
#  'къыбгъэдэкIуэтыжашщ',
#  'ирагъэшщIри',
#  'игъэIIхъэрат',
#  'кьысхуихьыр',
#  'ТТэшхьэку',
#  'Коцаре',
#  'Мухьэиэ-',
#  'зыгъэлъаIIIэщ',
#  'жынукым',
#  'блэгъуиIIлъэ',
#  'хэлIыфIыЭхьами',
#  'хъулъхугэъу',
#  'Зыхуэныкъуэи',
#  'яфIыжьтIэрт',
#  'къимыкIуэтыжьну',
#  'къыIIхуэхъуамэ',
#  'рифмэр',
#  'Темрыкьуэрэ',
#  'игъэбжъыфIэу',
#  'кьыфIахыж',
#  'ФхуэсшьтIа',
#  'хэIээбфу',
#  'тлъэиыкIыу',
#  'къикIыркым',
#  'кыхууегъэзэгъыртэкъым…',
#  'итынушщ…',
#  'Хьэиидрэ',
#  'уагъашщIэу',
#  'тхуогъээкIуэ',
#  'КъытIIэщIэувэнущ',
#  'укъызыхураджор',
#  'Графып',
#  'Исхьэкьрэ',
#  'йолIых',
#  'ТроIIIин',
#  'тригъэса-хэр',
#  'ездзыну:',
#  'къэIIхъунщIэфын',
#  'нашщхъуэнэ',
#  'IIсыунэкIэ',
#  'ебгъэтIысэххэи',
#  'Роксанрэ',
#  'ЕIIсэлъылIэу',
#  'хущIоIIлъ',
#  'неблэгънэ',
#  'фыкьезыхьэкI',
#  'сыкьихьэрт',
#  'Сахуэзэи',
#  'абыщыгъуэиуищIэлъэныкъуитIри',
#  'къыдэзгъэхьашщэрэт',
#  'хикъутыкIынып',
#  'шщIаукIыр',
#  'къыздэIэIIыкъунур',
#  'тхашьну',
#  'шщIыхэхъуэр',
#  'гъунэхэи',
#  'тхузэиыгъэкIуу',
#  'къышщыдимыгъэкIуалIэкIэ',
#  'ТТсиблыр',
#  'Темукеув',
#  'гуаIIэхэрт',
#  'къыбжъэхэуэу',
#  'формэхрэ',
#  'кьигъэкIэрэхъуэжри',
#  'зыхушщышщIэршщ',
#  'щылэжъын',
#  'шщызыIэригъэхьэ',
#  'фэ2кIэ',
#  'Кноцерт',
#  'Войеков',
#  'къыдрашщIейшщ',
#  'гукъыдэиыжащ',
#  'шщхьэшщылIыкIашщ',
#  'Iъэхъулъэхъу',
#  'докI-кьыдохьэжри',
#  'иъэзэнуми',
#  'сыщеIIлъыфынт',
#  'тримыгъэгуIIIхуауэ',
#  'ятеълалъэу',
#  'Алыхьталри',
#  'зэридзэIкын',
#  'тхуевгъэфIэкIуну',
#  'марIIIалхэм',
#  '523.70-рэ',
#  'уолъасээ',
#  'Нчэыхьхэр',
#  'командирып',
#  'Ронов',
#  'дыкъэтынукым',
#  'кыхуэплъхьакъым',
#  'зарижаным',
#  'хишщIыкIт',
#  'дыкъинэншщ',
#  'зариригъэджыным',
#  '…индустрие',
#  'хаързынэуэ',
#  'Заурбеак',
#  'пирикIуэрт',
#  'нэшщхъкIэ',
#  'теIIсэлъыхьт',
#  'зэхахр',
#  'Iулъадщэ',
#  'фчынкым',
#  'къесIIIэлIэжмэ',
#  'зарихэгъэзэгъапхъэр',
#  'щызыщагъэгъуIIщэ',
#  'зэшхеублэ',
#  'уезгъэIIIэну',
#  'телъыджот…',
#  'дахъуншщIэн',
#  'къытщIэгубжъащ',
#  'нэхулъэирэ',
#  'сызэрышщIэкIыжрэ',
#  'IIфIэщIт',
#  'зариукъуэдияуэ',
#  'къубатнй',
#  'къышщыIуихыжам',
#  'къысхуамышщIу',
#  'бидауркIэр',
#  'хэIIлъхьэнт',
#  'зыхъуж',
#  'шапсыгъып',
#  'зыбгъэдеIIIэри',
#  'кьызэраубыд',
#  'сышщIэшщIауэ',
#  'зыкъэзыгъэшьжи',
#  'къысшщыхъуашщ…',
#  'яхузIузыхари',
#  'зриIIхыр',
#  'зэгъэдаIэу',
#  'Аллоуэ6хьалыхь',
#  'кыIфIзэхэтуи',
#  'Хьэиырзэщ',
#  'УеIIIауэ',
#  'уIIсэуху',
#  'влъастыр',
#  'Дыхуърэ',
#  'зыхегъэщIэнып',
#  'схуIуиыурэ',
#  'фадафэирэ',
#  'фэфIхэр',
#  'кыхууитхат',
#  'УафэбгЫкъущхьэ',
#  'нышщхьэби',
#  'кьатриубыдауэ',
#  'яфIоъху',
#  'анэикIи',
#  'циркып',
#  'кIыхьыжъхэр',
#  'ЩIалшъхьа',
#  'сакьмэ',
#  'IIсэлъыхъухэм',
#  'обшщэ',
#  'IIредикат',
#  'экзаме:нхэр',
#  'зэхуихьэсшщ',
#  'гъэиахуэкуу',
#  'комунизму',
#  'слеснарь',
#  'Бжонкъурэм',
#  'IIлъытэрэ',
#  'Азебрайджаныр',
#  'IIсыналъэ',
#  'ДызэрышщIыхьэу',
#  'Зеанбт',
#  'жьзмыIэурэ',
#  'шщогуфIыкIыж',
#  'сыIIолъэщ',
#  'кьызэрытхэзэгъэнур',
#  'зариджалэм',
#  'хэIэбэну,и',
#  'щыIIэзэхэх',
#  'УIэкIуэлъаIуэу',
#  'кьызэрезэгъыр',
#  'къэдлэжъыжарщ',
#  'ОЛ',
#  'УзэфIэиыдыкъауэ',
#  'фIэдыхьэIIIхэну',
#  'шщыхаутэж',
#  'нэсакIтэ',
#  'хргъэхмэ',
#  'уэлбанэшщ…',
#  'кыхуудоплъейри',
#  'зыIуIIлъэр',
#  'эфэ',
#  'Жъызыхэсхынур',
#  'фыIIсэунуми',
#  'ятIагъур',
#  'къритхаршщ',
#  'сызыгъэуIIщIыIуа',
#  'кьыдэлът',
#  'яIэжтэкым',
#  'тIэъхуфэхъуэгъу',
#  'къащIихьэртэкым',
#  'яIIIхыурэ',
#  'клюIIIкэрэ',
#  'зыкIзышщхьэ',
#  'Сыщиущнй',
#  'щыIэнэщIып',
#  'къызоIIхъуэри',
#  'къакIуэиэ',
#  'IIсалъэм…',
#  'кыхуэдгъэкIынкъым',
#  'шщынэсар',
#  'кьыздэсхьынIакIи',
#  'с»игъафIэу',
#  'зэхыумгыъэхмэ',
#  'РесIIублике',
#  '1заводт',
#  'зариджэгухэм',
#  'гурылъ-хъуэIIсаIIIэ',
#  'къызэрешщIыIэкIыр',
#  'и«кIутэн',
#  'укьигъэгугъэнкIи',
#  'диIIIэу',
#  'узоцIыум-тIэ',
#  'кьеIысхарэ',
#  'шщахэхуи',
#  'еIIIхыдэрт',
#  'бог',
#  'къышщэкашщ',
#  'губзыгъэии',
#  'ПсынщIэ-IIсынщIэу',
#  'щамнй',
#  'уэрIIIэррэ',
#  'длыъыхъуэу',
#  'Мухьэиэд-цIыхубэ',
#  'мэжа3лIи',
#  'унафэшщIхэшщи',
#  'жЦейнэд',
#  'кьралъэфалIэ',
#  'Чухлекэрэ',
#  'ирикьузэн',
#  'дигугъэи',
#  'философр',
#  'ушщызекIуэн',
#  'дэкIэрахъэу',
#  'зыкъыIэщIиудыжьну',
#  'IIищIэжарэ',
#  'къахуихуэркым',
#  'къуабэбжъабэжърэ',
#  'умышщIэхушщ',
#  'епцIыжынукым',
#  'Къетыкьуэхэрэ',
#  'яхуэсшщIа',
#  'IIьесэхэри',
#  'хезгъэукIакым',
#  'Зулиханрэ',
#  'интенднатыр',
#  'зэхуаIуатэ у',
#  'кьимыгъэгугъэж',
#  'т5езгъэхьа',
#  'дыкъаIIлъэмэ',
#  'шщызэшщхь',
#  'кыхууихьынтэкъым',
#  'церIIкIэ',
#  'къыткIэшщIэдэIухьыр',
#  'зыхиудыгъуэIIащ',
#  'телъхьэтн',
#  'мыцIыхум',
#  'Арбта',
#  'кIэлъыIIхъэрар',
#  'гугъэкIэутэкым',
#  'къиIуаIIхъэхэр',
#  'дахушщытыну',
#  'Iушщти',
#  'яхэзагэъ',
#  'йохьэи',
#  'зарихэтар…',
#  'кыхуихыртэкъыми',
#  'яхурфэ',
#  'теориые',
#  'ямыгъэIэIIхъуэфу',
#  'зыщигъэIIсэху',
#  'Сытеълэну',
#  'зэIущIэIIIхуэ',
#  'къызэрежъэм',
#  'тхакIуэгъухэии',
#  'дзажоналъихыр',
#  'СшщIэну',
#  'кьэкIуэкIам',
#  'лъэрсэ',
#  'зарикIуэцIригъэкIыфыр',
#  'ирисондэджорырт',
#  'Укьызэрытэджу',
#  'зарищхьэпридзар-щэ',
#  'кыхууищIынт',
#  'къышщIедвгъэгъэдзыж',
#  'ираутх',
#  'къыстегуIIлIэу',
#  'лейзехьэхэи',
#  'Гундэж',
#  'фыдо',
#  'изгъэIэану',
#  'клуаккIэ',
#  'реIIродукцэхэр',
#  'сыдэкIуэнкым',
#  'ухелъафэх',
#  'къышщIилъэфашщ',
#  'зыIихыжу',
#  'къыщежъамрэ',
#  'дыкъигъэгъуэзэншщ',
#  'Лэгъупэжьып',
#  'къадэгужъеижри',
#  'кыхууащIхэр',
#  'хэкуIэтахэр',
#  'тобэкьеIыхгуэ',
#  'теффыхьыжьнщ',
#  'укъишщIыншщ',
#  'ГушьIэри',
#  'IувыIIIхуэхэр',
#  'уГрунц',
#  'КъыдоIIлъейри',
#  'ЩIалэгъаулэт',
#  'зэIузэIIэщкIэ',
#  'блэжъынт',
#  'игъэувыжьну',
#  'гъэбыадрэ',
#  'ныкъуэтххэи',
#  'IIIэцIеижырт',
#  'Хъаныжъхэр',
#  'чЯыцэ',
#  'Зызогъэшщхъри',
#  'нэхъыфIын-т',
#  'кьызэбэкIыу',
#  'IIшахъуалъэ',
#  'хэджорэза',
#  'хузэихлъхьэрт',
#  'УнафэщIхэи',
#  'Алексндровнэ',
#  'уфээкIри',
#  'зыдебгъэхьэхыIуашщ',
#  'ираIIхыжауэ',
#  'екIуашщи',
#  'кьриудыхын',
#  'шщIыбу',
#  'леймкэ',
#  'ЩызрэихьэлIари',
#  'Егороивч',
#  'зыдъэхьэзырауэ',
#  'шщысхьыншщ',
#  'кърашщIылIэну',
#  'заририIуэр',
#  'хуэIэзашщэу',
#  'нн-а-тIэ',
#  'ятелаър',
#  'сигъэIIIэчари',
#  'сышьнэурэ',
#  'зыкъытрагъэшщIауэ',
#  'кьэуэжхэр',
#  'ящхьэIIрыкIыжмэ',
#  'дыкъыщIашьжурэ',
#  'кыхуэмыкIыну',
#  'заризэIумыбзым',
#  'зрекъузылIэи',
#  'къысхуишэжьрт',
#  'утезгъэлэжъэну',
#  'къеIIхьэлIэри',
#  'хьэдрыхэшщ',
#  'зрирэ',
#  'Къэзгъанэиэ',
#  'емышэжьр',
#  'сыкьилъыхъуэнт',
#  'зеЩзыгъэза',
#  'Фарухьэр',
#  'къызэрыIIщыгугъари',
#  'кьэукьубея',
#  'схуэиыгъэхъей',
#  'ЗыхуэуIа',
#  'сызэрыакъылынIIIэр',
#  'бгъуитIып',
#  'Бидонэрашщ',
#  'зарифIэкIыхьыр',
#  'зэрахуэии',
#  'заризмыщIэжыр',
#  'игъэщхьэрыуэркым',
#  'зэригъэудэIужынып',
#  'къигъэчашщ',
#  'гуIIышхуэ-гуIIышхуэурэ',
#  'къигуIIсысыжыну',
#  'кхэ',
#  'щыIIоIIлъэ',
#  'хуэIIаи',
#  'Щытыхункэ',
#  'вагъэбдзумэшщIэу',
#  'къызэригъэлъэгъуэжьрщ',
#  'эхзыгъэт',
#  'ьХэжмурату…',
#  'ЩыжьтIэм',
#  'щимыгъэтыжьххэ',
#  'Самаринып',
#  'сызэшщIиIулIауэ',
#  'Назо',
#  'емыIIцIыжрэ',
#  'сэIлъытауэ',
#  'Сэнтхып',
#  'жокъуауэ',
#  'Жъызбрунри',
#  'гукъутэгъуэи',
#  'къыдэкIахэшщ',
#  'гъэшщхъыныр',
#  'дыгъэбжьж',
#  'дредзей-кьредзых',
#  'балъкьэрми',
#  'сеIIлъыжащ',
#  'кIашщхъэ',
#  'фагъэт',
#  'IэубыдыIIIэншэр',
#  'къытшщыхуэншщи',
#  'баррикдаэкIэ',
#  'хэкIуэдэншщ',
#  'ескуртэкым',
#  'къышщышщIигъэкIыжам',
#  'шщрагъэтIылъыкIашщ',
#  'къыдожъу',
#  'сыхэзыубыдра',
#  'шщымыхъункIэ',
#  'IIIогенцукова',
#  'шщIыхьэ-къышщIэкIыжу',
#  'шщIэхуэн',
#  'еIIхыжащ',
#  'кьадыгъун',
#  'сабиигъуэ-шщIалэгъуэр',
#  'укъыщIыщIэIIщар',
#  'гуэщыжъыр',
#  'Хьэшщыкъ',
#  'кьысхуикIхэр',
#  'алыжхэр',
#  'ьэнэф',
#  'кружокып',
#  'къэIушщашщэ',
#  'яхузэмыгъэIIэщмэ-щэ',
#  'къывогъэIIцIэж',
#  'идгъэлъынукым',
#  'фIагъэжьнур',
#  'фрихьэлIакьэ',
#  'Аргуэри',
#  'зэригъэзахуэирэ',
#  'хьэIIшыIIуи',
#  'кьыркуэ',
#  'жъачэм',
#  'дызэкурсашщ',
#  'заризаIэт',
#  'кьытхинэжари',
#  'зырызып',
#  'хуэзгъуэтакым',
#  'ТIымыжъми',
#  'гуэлж',
#  'Багъып',
#  'къагъэкъуэнIIIат',
#  'къуакIэбгЫкIэми',
#  'щыдухыжьнури',
#  'къышщыхуэхъукIэ',
#  'уоIIIэсри…',
#  'загуи',
#  'хунгъэхьэзыра',
#  'къэщIэрэщIэжьныгъэ',
#  'шщыгъуазэт-тIэ',
#  'зыкъриублэрэкIэхашщ',
#  'дакъылъэшщIыхьэри…',
#  'сэзымыгъэшщIыр',
#  'ухудэII-',
#  'узэхъуаIIсэр',
#  'тшщIэнур',
#  'Жъэгузэва',
#  'кьимыгъэтIысу',
#  'зыщIиIэжъэмрэ',
#  'Гъубжьмрэ',
#  'зыхэмылэжъыхьа',
#  'фIэткым',
#  'IIщыри',
#  'Хэ?кI',
#  'къалэкIэршщ',
#  'къызэрехьэжъа',
#  'ЪЩотхъу',
#  'сыкъэкIуэжынутэкым',
#  'зыхиушщэхуашщ',
#  'еджагъэIIIхуэхэри',
#  'индоевроIIеиджхэми',
#  'номерып',
#  ...}

# %%
with open('../data/processed/spell_checker/synthetic_spelling_errors.txt', 'w') as f:
    f.write('\n'.join(synthetic_spelling_errors))
