# %%
import csv
import pandas as pd
token_dist_dir = '../data/processed/token_distribution'

stem_df = pd.read_csv(f'{token_dist_dir}/stem_full_words.csv', sep=',', header=0, quoting=csv.QUOTE_MINIMAL, quotechar='"')

# %%
stem_df
# Out:
#        stem_ng_len        stem  word_ng_len        word    template  \
# 0                1        Iами            1        Iами        ????
# 1                1        Iамэ            1        Iамэ        ????
# 2                1       Iуатэ            1       Iуатэ       ?????
# 3                1        Iуащ            1        Iуащ        ????
# 4                1        IукI            1        IукI        ????
# ...            ...         ...          ...         ...         ...
# 14238            6    щхьэхуит            6    щхьэхуит    ????????
# 14239            6   щхьэщыхьэ            6   щхьэщыхьэ   ?????????
# 14240            6   щэхуакIуэ            6   щэхуакIуэ   ?????????
# 14241            6   эртэкъыми            6   эртэкъыми   ?????????
# 14242            6  якIэлъыплъ            6  якIэлъыплъ  ??????????
#
#                 tokens  stem_is_full_word
# 0                 Iами               True
# 1                 Iамэ               True
# ...
